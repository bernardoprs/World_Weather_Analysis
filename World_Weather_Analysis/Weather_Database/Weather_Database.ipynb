# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 738

# %%
#Import dependencies
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | upernavik
# Processing Record 3 of Set 1 | bogdana
# Processing Record 4 of Set 1 | acari
# Processing Record 5 of Set 1 | hirara
# Processing Record 6 of Set 1 | aginskoye
# Processing Record 7 of Set 1 | padang
# Processing Record 8 of Set 1 | longyearbyen
# Processing Record 9 of Set 1 | konigswinter
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | meulaboh
# Processing Record 13 of Set 1 | sept-iles
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | bredasdorp
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | rosetta
# Processing Record 18 of Set 1 | gat
# Processing Record 19 of Set 1 | tautira
# Processing Record 20 of Set 1 | atuona
# Processing Record 21 of Set 1 | waingapu
# Processing Record 22 of Set 1 | kaitangata
# Processing Record 23 of Set 1 | thompson
# Processing Record 24 of Set 1 | san jeronimo
# Processing Record 25 of Set 1 | gidole
# Processing Record 26 of Set 1 | berezna
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | yerbogachen
# Processing Record 29 of Set 1 | pangody
# Processing Record 30 of Set 1 | kaniama
# Processing Record 31 of Set 1 | kapaa
# Processing Record 32 of Set 1 | colac
# Processing Record 33 of Set 1 | saint-joseph
# Processing Record 34 of Set 1 | stepnyak
# Processing Record 35 of Set 1 | tambopata
# Processing Record 36 of Set 1 | san quintin
# Processing Record 37 of Set 1 | nantucket
# Processing Record 38 of Set 1 | carnarvon
# Processing Record 39 of Set 1 | khatanga
# Processing Record 40 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | avanigadda
# Processing Record 43 of Set 1 | nenjiang
# Processing Record 44 of Set 1 | adrar
# Processing Record 45 of Set 1 | trairi
# Processing Record 46 of Set 1 | provideniya
# Processing Record 47 of Set 1 | tasiilaq
# Processing Record 48 of Set 1 | clyde river
# Processing Record 49 of Set 1 | nikki
# Processing Record 50 of Set 1 | barrow
# Processing Record 1 of Set 2 | port blair
# Processing Record 2 of Set 2 | riyadh
# Processing Record 3 of Set 2 | maarianhamina
# Processing Record 4 of Set 2 | jamestown
# Processing Record 5 of Set 2 | la asuncion
# Processing Record 6 of Set 2 | hermanus
# Processing Record 7 of Set 2 | kautokeino
# Processing Record 8 of Set 2 | severo-kurilsk
# Processing Record 9 of Set 2 | qaanaaq
# Processing Record 10 of Set 2 | avera
# Processing Record 11 of Set 2 | port alfred
# Processing Record 12 of Set 2 | sovetskiy
# Processing Record 13 of Set 2 | butaritari
# Processing Record 14 of Set 2 | naze
# Processing Record 15 of Set 2 | constitucion
# Processing Record 16 of Set 2 | vestbygda
# City not found. Skipping...
# Processing Record 17 of Set 2 | seymchan
# Processing Record 18 of Set 2 | gurskoye
# City not found. Skipping...
# Processing Record 19 of Set 2 | castro
# Processing Record 20 of Set 2 | havelock
# Processing Record 21 of Set 2 | norman wells
# Processing Record 22 of Set 2 | george
# Processing Record 23 of Set 2 | faanui
# Processing Record 24 of Set 2 | kahului
# Processing Record 25 of Set 2 | georgetown
# Processing Record 26 of Set 2 | vila velha
# Processing Record 27 of Set 2 | tiksi
# Processing Record 28 of Set 2 | bud
# Processing Record 29 of Set 2 | vardo
# Processing Record 30 of Set 2 | mankera
# Processing Record 31 of Set 2 | shizunai
# Processing Record 32 of Set 2 | bambous virieux
# Processing Record 33 of Set 2 | indramayu
# Processing Record 34 of Set 2 | souillac
# Processing Record 35 of Set 2 | acapulco
# Processing Record 36 of Set 2 | hobart
# Processing Record 37 of Set 2 | yarmouth
# Processing Record 38 of Set 2 | hithadhoo
# Processing Record 39 of Set 2 | ilulissat
# Processing Record 40 of Set 2 | kuala terengganu
# Processing Record 41 of Set 2 | torbay
# Processing Record 42 of Set 2 | kangaatsiaq
# Processing Record 43 of Set 2 | lagoa
# Processing Record 44 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 2 | alexandria
# Processing Record 46 of Set 2 | wisconsin rapids
# Processing Record 47 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 2 | yellowknife
# Processing Record 50 of Set 2 | naifaru
# Processing Record 1 of Set 3 | chokurdakh
# Processing Record 2 of Set 3 | koppang
# Processing Record 3 of Set 3 | ishigaki
# Processing Record 4 of Set 3 | senanga
# Processing Record 5 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 6 of Set 3 | airai
# Processing Record 7 of Set 3 | wahran
# City not found. Skipping...
# Processing Record 8 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 3 | port elizabeth
# Processing Record 10 of Set 3 | avarua
# Processing Record 11 of Set 3 | ponta do sol
# Processing Record 12 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 3 | hasaki
# Processing Record 14 of Set 3 | shimoda
# Processing Record 15 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 16 of Set 3 | victoria
# Processing Record 17 of Set 3 | luangwa
# Processing Record 18 of Set 3 | east london
# Processing Record 19 of Set 3 | kodiak
# Processing Record 20 of Set 3 | jezerski
# Processing Record 21 of Set 3 | lugovskiy
# City not found. Skipping...
# Processing Record 22 of Set 3 | hilo
# Processing Record 23 of Set 3 | salalah
# Processing Record 24 of Set 3 | soyo
# Processing Record 25 of Set 3 | turukhansk
# Processing Record 26 of Set 3 | albany
# Processing Record 27 of Set 3 | bethel
# Processing Record 28 of Set 3 | bunia
# Processing Record 29 of Set 3 | hambantota
# Processing Record 30 of Set 3 | port hawkesbury
# Processing Record 31 of Set 3 | qurayyat
# Processing Record 32 of Set 3 | tuktoyaktuk
# Processing Record 33 of Set 3 | chara
# Processing Record 34 of Set 3 | mallaig
# Processing Record 35 of Set 3 | nikolskoye
# Processing Record 36 of Set 3 | tuatapere
# Processing Record 37 of Set 3 | rincon
# Processing Record 38 of Set 3 | new norfolk
# Processing Record 39 of Set 3 | mount isa
# Processing Record 40 of Set 3 | hunza
# City not found. Skipping...
# Processing Record 41 of Set 3 | veinte de noviembre
# Processing Record 42 of Set 3 | fortuna
# Processing Record 43 of Set 3 | uyemskiy
# Processing Record 44 of Set 3 | bluff
# Processing Record 45 of Set 3 | port macquarie
# Processing Record 46 of Set 3 | boundiali
# Processing Record 47 of Set 3 | itaituba
# Processing Record 48 of Set 3 | terney
# Processing Record 49 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 3 | talnakh
# Processing Record 1 of Set 4 | sao filipe
# Processing Record 2 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 4 | mumford
# Processing Record 4 of Set 4 | rudnaya pristan
# Processing Record 5 of Set 4 | krasnoarmeysk
# Processing Record 6 of Set 4 | agadez
# Processing Record 7 of Set 4 | seoul
# Processing Record 8 of Set 4 | metro
# Processing Record 9 of Set 4 | namibe
# Processing Record 10 of Set 4 | saint-philippe
# Processing Record 11 of Set 4 | san patricio
# Processing Record 12 of Set 4 | port lincoln
# Processing Record 13 of Set 4 | the pas
# Processing Record 14 of Set 4 | nishihara
# Processing Record 15 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 16 of Set 4 | svetlaya
# Processing Record 17 of Set 4 | lebu
# Processing Record 18 of Set 4 | okha
# Processing Record 19 of Set 4 | tobol
# Processing Record 20 of Set 4 | buraydah
# Processing Record 21 of Set 4 | tivaouane
# Processing Record 22 of Set 4 | chuy
# Processing Record 23 of Set 4 | waipawa
# Processing Record 24 of Set 4 | tambovka
# Processing Record 25 of Set 4 | sioux lookout
# Processing Record 26 of Set 4 | ambilobe
# Processing Record 27 of Set 4 | pecos
# Processing Record 28 of Set 4 | mananara
# Processing Record 29 of Set 4 | lodja
# Processing Record 30 of Set 4 | port hedland
# Processing Record 31 of Set 4 | tessalit
# Processing Record 32 of Set 4 | dikson
# Processing Record 33 of Set 4 | itarema
# Processing Record 34 of Set 4 | kalmunai
# Processing Record 35 of Set 4 | murray bridge
# Processing Record 36 of Set 4 | abu samrah
# Processing Record 37 of Set 4 | te anau
# Processing Record 38 of Set 4 | zhuhai
# Processing Record 39 of Set 4 | dingle
# Processing Record 40 of Set 4 | port shepstone
# Processing Record 41 of Set 4 | kuhestan
# City not found. Skipping...
# Processing Record 42 of Set 4 | tyukhtet
# Processing Record 43 of Set 4 | saldanha
# Processing Record 44 of Set 4 | esperance
# Processing Record 45 of Set 4 | sarakhs
# Processing Record 46 of Set 4 | muroto
# Processing Record 47 of Set 4 | chumikan
# Processing Record 48 of Set 4 | mitu
# Processing Record 49 of Set 4 | staryy nadym
# Processing Record 50 of Set 4 | geraldton
# Processing Record 1 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 5 | buchanan
# Processing Record 3 of Set 5 | byron bay
# Processing Record 4 of Set 5 | cartagena
# Processing Record 5 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 5 | kuusamo
# Processing Record 7 of Set 5 | necochea
# Processing Record 8 of Set 5 | hamilton
# Processing Record 9 of Set 5 | arraial do cabo
# Processing Record 10 of Set 5 | zhanaozen
# Processing Record 11 of Set 5 | uk
# City not found. Skipping...
# Processing Record 12 of Set 5 | bafra
# Processing Record 13 of Set 5 | zyryanka
# Processing Record 14 of Set 5 | den helder
# Processing Record 15 of Set 5 | higuey
# City not found. Skipping...
# Processing Record 16 of Set 5 | bengkulu
# Processing Record 17 of Set 5 | mosetse
# Processing Record 18 of Set 5 | namuac
# Processing Record 19 of Set 5 | mackay
# Processing Record 20 of Set 5 | cooma
# Processing Record 21 of Set 5 | hare bay
# Processing Record 22 of Set 5 | san marcos
# Processing Record 23 of Set 5 | vila franca do campo
# Processing Record 24 of Set 5 | mackenzie
# Processing Record 25 of Set 5 | mar del plata
# Processing Record 26 of Set 5 | coquimbo
# Processing Record 27 of Set 5 | rorvik
# Processing Record 28 of Set 5 | sibolga
# Processing Record 29 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 5 | lerwick
# Processing Record 31 of Set 5 | boende
# Processing Record 32 of Set 5 | sitka
# Processing Record 33 of Set 5 | sawtell
# Processing Record 34 of Set 5 | haines junction
# Processing Record 35 of Set 5 | puerto ayora
# Processing Record 36 of Set 5 | cap malheureux
# Processing Record 37 of Set 5 | price
# Processing Record 38 of Set 5 | galdar
# Processing Record 39 of Set 5 | cabo san lucas
# Processing Record 40 of Set 5 | quatre cocos
# Processing Record 41 of Set 5 | stupino
# Processing Record 42 of Set 5 | arona
# Processing Record 43 of Set 5 | klaksvik
# Processing Record 44 of Set 5 | lumberton
# Processing Record 45 of Set 5 | kununurra
# Processing Record 46 of Set 5 | berbera
# Processing Record 47 of Set 5 | barguzin
# Processing Record 48 of Set 5 | jalu
# Processing Record 49 of Set 5 | aksu
# Processing Record 50 of Set 5 | awbari
# Processing Record 1 of Set 6 | gasa
# Processing Record 2 of Set 6 | tocopilla
# Processing Record 3 of Set 6 | andevoranto
# City not found. Skipping...
# Processing Record 4 of Set 6 | magadan
# Processing Record 5 of Set 6 | sorong
# Processing Record 6 of Set 6 | lentekhi
# Processing Record 7 of Set 6 | rio gallegos
# Processing Record 8 of Set 6 | nanortalik
# Processing Record 9 of Set 6 | sabha
# Processing Record 10 of Set 6 | ganzhou
# Processing Record 11 of Set 6 | trindade
# Processing Record 12 of Set 6 | na wa
# Processing Record 13 of Set 6 | sidi bu zayd
# City not found. Skipping...
# Processing Record 14 of Set 6 | mehamn
# Processing Record 15 of Set 6 | nsanje
# Processing Record 16 of Set 6 | fort madison
# Processing Record 17 of Set 6 | kirakira
# Processing Record 18 of Set 6 | pevek
# Processing Record 19 of Set 6 | qaqortoq
# Processing Record 20 of Set 6 | pitimbu
# Processing Record 21 of Set 6 | yulara
# Processing Record 22 of Set 6 | elliot lake
# Processing Record 23 of Set 6 | cayenne
# Processing Record 24 of Set 6 | luderitz
# Processing Record 25 of Set 6 | kruisfontein
# Processing Record 26 of Set 6 | caravelas
# Processing Record 27 of Set 6 | baiyin
# Processing Record 28 of Set 6 | itumba
# Processing Record 29 of Set 6 | rio negrinho
# Processing Record 30 of Set 6 | dezful
# Processing Record 31 of Set 6 | mahebourg
# Processing Record 32 of Set 6 | mercedes
# Processing Record 33 of Set 6 | isangel
# Processing Record 34 of Set 6 | bahadurgarh
# Processing Record 35 of Set 6 | cockburn town
# Processing Record 36 of Set 6 | sarangani
# Processing Record 37 of Set 6 | tawnat
# City not found. Skipping...
# Processing Record 38 of Set 6 | ambodifototra
# City not found. Skipping...
# Processing Record 39 of Set 6 | shumskiy
# Processing Record 40 of Set 6 | vzmorye
# Processing Record 41 of Set 6 | parabel
# Processing Record 42 of Set 6 | port-gentil
# Processing Record 43 of Set 6 | kananga
# Processing Record 44 of Set 6 | lazaro cardenas
# Processing Record 45 of Set 6 | skagastrond
# City not found. Skipping...
# Processing Record 46 of Set 6 | komsomolskiy
# Processing Record 47 of Set 6 | nogliki
# Processing Record 48 of Set 6 | los llanos de aridane
# Processing Record 49 of Set 6 | puerto escondido
# Processing Record 50 of Set 6 | maragogi
# Processing Record 1 of Set 7 | cuenca
# Processing Record 2 of Set 7 | kloulklubed
# Processing Record 3 of Set 7 | berdigestyakh
# Processing Record 4 of Set 7 | wang saphung
# Processing Record 5 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 7 | bosaso
# Processing Record 7 of Set 7 | villa guerrero
# Processing Record 8 of Set 7 | cherskiy
# Processing Record 9 of Set 7 | zalesovo
# Processing Record 10 of Set 7 | meghraj
# Processing Record 11 of Set 7 | were ilu
# Processing Record 12 of Set 7 | port augusta
# Processing Record 13 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 14 of Set 7 | rajbiraj
# Processing Record 15 of Set 7 | katsuura
# Processing Record 16 of Set 7 | mocuba
# Processing Record 17 of Set 7 | bodden town
# Processing Record 18 of Set 7 | council bluffs
# Processing Record 19 of Set 7 | ancud
# Processing Record 20 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 7 | vanimo
# Processing Record 22 of Set 7 | tromso
# Processing Record 23 of Set 7 | dondo
# Processing Record 24 of Set 7 | marystown
# Processing Record 25 of Set 7 | kavaratti
# Processing Record 26 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 7 | lompoc
# Processing Record 28 of Set 7 | isla mujeres
# Processing Record 29 of Set 7 | ereymentau
# Processing Record 30 of Set 7 | saint george
# Processing Record 31 of Set 7 | balykshi
# Processing Record 32 of Set 7 | pangnirtung
# Processing Record 33 of Set 7 | eatonton
# Processing Record 34 of Set 7 | la ronge
# Processing Record 35 of Set 7 | cozumel
# Processing Record 36 of Set 7 | guerrero negro
# Processing Record 37 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 7 | imeni poliny osipenko
# Processing Record 39 of Set 7 | san carlos de bariloche
# Processing Record 40 of Set 7 | sampit
# Processing Record 41 of Set 7 | januaria
# Processing Record 42 of Set 7 | muravlenko
# Processing Record 43 of Set 7 | tecoanapa
# Processing Record 44 of Set 7 | rio grande
# Processing Record 45 of Set 7 | vostok
# Processing Record 46 of Set 7 | surazh
# Processing Record 47 of Set 7 | am timan
# Processing Record 48 of Set 7 | kiama
# Processing Record 49 of Set 7 | cidreira
# Processing Record 50 of Set 7 | ahuimanu
# Processing Record 1 of Set 8 | kabalo
# Processing Record 2 of Set 8 | loreto
# Processing Record 3 of Set 8 | puerto el triunfo
# Processing Record 4 of Set 8 | richards bay
# Processing Record 5 of Set 8 | quebo
# Processing Record 6 of Set 8 | coihaique
# Processing Record 7 of Set 8 | ozernovskiy
# Processing Record 8 of Set 8 | maceio
# Processing Record 9 of Set 8 | atherton
# Processing Record 10 of Set 8 | varhaug
# Processing Record 11 of Set 8 | loralai
# Processing Record 12 of Set 8 | lavrentiya
# Processing Record 13 of Set 8 | praia da vitoria
# Processing Record 14 of Set 8 | winnemucca
# Processing Record 15 of Set 8 | korla
# Processing Record 16 of Set 8 | prince rupert
# Processing Record 17 of Set 8 | laguna
# Processing Record 18 of Set 8 | gold coast
# Processing Record 19 of Set 8 | ribeira grande
# Processing Record 20 of Set 8 | wasilla
# Processing Record 21 of Set 8 | presidente olegario
# Processing Record 22 of Set 8 | olinda
# Processing Record 23 of Set 8 | hofn
# Processing Record 24 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 25 of Set 8 | yarkovo
# Processing Record 26 of Set 8 | berlevag
# Processing Record 27 of Set 8 | rzhev
# Processing Record 28 of Set 8 | bibiani
# Processing Record 29 of Set 8 | fort nelson
# Processing Record 30 of Set 8 | tevaitoa
# Processing Record 31 of Set 8 | roald
# Processing Record 32 of Set 8 | gilbert
# Processing Record 33 of Set 8 | sorland
# Processing Record 34 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 35 of Set 8 | springdale
# Processing Record 36 of Set 8 | amuntai
# Processing Record 37 of Set 8 | portobelo
# Processing Record 38 of Set 8 | iquitos
# Processing Record 39 of Set 8 | murupara
# Processing Record 40 of Set 8 | murgab
# Processing Record 41 of Set 8 | russell
# Processing Record 42 of Set 8 | saint-leu
# Processing Record 43 of Set 8 | batagay-alyta
# Processing Record 44 of Set 8 | narsaq
# Processing Record 45 of Set 8 | bend
# Processing Record 46 of Set 8 | port alberni
# Processing Record 47 of Set 8 | kavieng
# Processing Record 48 of Set 8 | bilma
# Processing Record 49 of Set 8 | columbus
# Processing Record 50 of Set 8 | arkhangelos
# City not found. Skipping...
# Processing Record 1 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 9 | gravdal
# Processing Record 3 of Set 9 | faya
# Processing Record 4 of Set 9 | fairbanks
# Processing Record 5 of Set 9 | yakeshi
# Processing Record 6 of Set 9 | ewo
# Processing Record 7 of Set 9 | yar-sale
# Processing Record 8 of Set 9 | el wasta
# City not found. Skipping...
# Processing Record 9 of Set 9 | waupun
# Processing Record 10 of Set 9 | riberalta
# Processing Record 11 of Set 9 | sao joao da barra
# Processing Record 12 of Set 9 | cururupu
# Processing Record 13 of Set 9 | ipswich
# Processing Record 14 of Set 9 | saint-georges
# Processing Record 15 of Set 9 | lufilufi
# Processing Record 16 of Set 9 | solnechnyy
# Processing Record 17 of Set 9 | carmelo
# Processing Record 18 of Set 9 | rawson
# Processing Record 19 of Set 9 | west odessa
# Processing Record 20 of Set 9 | tamandare
# Processing Record 21 of Set 9 | vestmanna
# Processing Record 22 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 9 | pisco
# Processing Record 24 of Set 9 | whyalla
# Processing Record 25 of Set 9 | ouro fino
# Processing Record 26 of Set 9 | pangoa
# Processing Record 27 of Set 9 | izhevskoye
# Processing Record 28 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 9 | thinadhoo
# Processing Record 30 of Set 9 | margate
# Processing Record 31 of Set 9 | bardiyah
# Processing Record 32 of Set 9 | ovalle
# Processing Record 33 of Set 9 | susangerd
# Processing Record 34 of Set 9 | grammichele
# Processing Record 35 of Set 9 | yumen
# Processing Record 36 of Set 9 | qasigiannguit
# Processing Record 37 of Set 9 | codrington
# Processing Record 38 of Set 9 | guane
# Processing Record 39 of Set 9 | seshcha
# Processing Record 40 of Set 9 | aguimes
# Processing Record 41 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 42 of Set 9 | ponta delgada
# Processing Record 43 of Set 9 | kamina
# Processing Record 44 of Set 9 | kidal
# Processing Record 45 of Set 9 | hengshui
# Processing Record 46 of Set 9 | kokopo
# Processing Record 47 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 48 of Set 9 | hirado
# Processing Record 49 of Set 9 | mayo
# Processing Record 50 of Set 9 | hualmay
# Processing Record 1 of Set 10 | daru
# Processing Record 2 of Set 10 | mandalgovi
# Processing Record 3 of Set 10 | kokkola
# Processing Record 4 of Set 10 | aklavik
# Processing Record 5 of Set 10 | puerto del rosario
# Processing Record 6 of Set 10 | senneterre
# Processing Record 7 of Set 10 | wajir
# Processing Record 8 of Set 10 | tranas
# Processing Record 9 of Set 10 | labuhan
# Processing Record 10 of Set 10 | lasa
# Processing Record 11 of Set 10 | maniitsoq
# Processing Record 12 of Set 10 | san cristobal
# Processing Record 13 of Set 10 | garoua
# Processing Record 14 of Set 10 | bacuit
# City not found. Skipping...
# Processing Record 15 of Set 10 | karratha
# Processing Record 16 of Set 10 | buqayq
# City not found. Skipping...
# Processing Record 17 of Set 10 | tete
# Processing Record 18 of Set 10 | puerto colombia
# Processing Record 19 of Set 10 | waitati
# Processing Record 20 of Set 10 | husavik
# Processing Record 21 of Set 10 | whitehorse
# Processing Record 22 of Set 10 | muzquiz
# City not found. Skipping...
# Processing Record 23 of Set 10 | kupang
# Processing Record 24 of Set 10 | fomboni
# Processing Record 25 of Set 10 | severo-yeniseyskiy
# Processing Record 26 of Set 10 | anjozorobe
# Processing Record 27 of Set 10 | cilegon
# Processing Record 28 of Set 10 | winslow
# Processing Record 29 of Set 10 | madimba
# Processing Record 30 of Set 10 | pacific grove
# Processing Record 31 of Set 10 | verkhoyansk
# Processing Record 32 of Set 10 | chapais
# Processing Record 33 of Set 10 | lata
# Processing Record 34 of Set 10 | west lorne
# Processing Record 35 of Set 10 | albion
# Processing Record 36 of Set 10 | mukhen
# Processing Record 37 of Set 10 | turan
# Processing Record 38 of Set 10 | quelimane
# Processing Record 39 of Set 10 | sur
# Processing Record 40 of Set 10 | xinmin
# Processing Record 41 of Set 10 | urumqi
# Processing Record 42 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 43 of Set 10 | grindavik
# Processing Record 44 of Set 10 | formoso do araguaia
# City not found. Skipping...
# Processing Record 45 of Set 10 | shawnee
# Processing Record 46 of Set 10 | tezu
# Processing Record 47 of Set 10 | tongliao
# Processing Record 48 of Set 10 | iqaluit
# Processing Record 49 of Set 10 | hay river
# Processing Record 50 of Set 10 | nayoro
# Processing Record 1 of Set 11 | nizwa
# Processing Record 2 of Set 11 | lapeer
# Processing Record 3 of Set 11 | urucara
# Processing Record 4 of Set 11 | dicabisagan
# Processing Record 5 of Set 11 | amurzet
# Processing Record 6 of Set 11 | panzhihua
# Processing Record 7 of Set 11 | chicama
# Processing Record 8 of Set 11 | jardim
# Processing Record 9 of Set 11 | arman
# Processing Record 10 of Set 11 | vila do maio
# Processing Record 11 of Set 11 | pangkalanbuun
# Processing Record 12 of Set 11 | palestine
# Processing Record 13 of Set 11 | rome
# Processing Record 14 of Set 11 | penzance
# Processing Record 15 of Set 11 | coahuayana
# Processing Record 16 of Set 11 | lovozero
# Processing Record 17 of Set 11 | marzuq
# Processing Record 18 of Set 11 | muros
# Processing Record 19 of Set 11 | champerico
# Processing Record 20 of Set 11 | gumushane
# City not found. Skipping...
# Processing Record 21 of Set 11 | belaya gora
# Processing Record 22 of Set 11 | jabiru
# City not found. Skipping...
# Processing Record 23 of Set 11 | yangjiang
# Processing Record 24 of Set 11 | evanston
# Processing Record 25 of Set 11 | porbandar
# Processing Record 26 of Set 11 | brownsville
# Processing Record 27 of Set 11 | fukuma
# Processing Record 28 of Set 11 | linshu
# City not found. Skipping...
# Processing Record 29 of Set 11 | proletariy
# Processing Record 30 of Set 11 | puerto leguizamo
# Processing Record 31 of Set 11 | colesberg
# Processing Record 32 of Set 11 | ca mau
# Processing Record 33 of Set 11 | rio bananal
# Processing Record 34 of Set 11 | bereda
# Processing Record 35 of Set 11 | filingue
# Processing Record 36 of Set 11 | bozhou
# Processing Record 37 of Set 11 | mount gambier
# Processing Record 38 of Set 11 | abonnema
# Processing Record 39 of Set 11 | prabumulih
# Processing Record 40 of Set 11 | itai
# Processing Record 41 of Set 11 | zdvinsk
# Processing Record 42 of Set 11 | san rafael
# Processing Record 43 of Set 11 | lorengau
# Processing Record 44 of Set 11 | shelburne
# Processing Record 45 of Set 11 | bouca
# Processing Record 46 of Set 11 | santa cruz
# Processing Record 47 of Set 11 | axim
# Processing Record 48 of Set 11 | punuare
# Processing Record 49 of Set 11 | verkhnevilyuysk
# Processing Record 50 of Set 11 | matagami
# Processing Record 1 of Set 12 | hat yai
# Processing Record 2 of Set 12 | ballina
# Processing Record 3 of Set 12 | porto novo
# Processing Record 4 of Set 12 | seevetal
# Processing Record 5 of Set 12 | kudahuvadhoo
# Processing Record 6 of Set 12 | alekseyevsk
# Processing Record 7 of Set 12 | vestmannaeyjar
# Processing Record 8 of Set 12 | sinnamary
# Processing Record 9 of Set 12 | kaka
# Processing Record 10 of Set 12 | nelson bay
# Processing Record 11 of Set 12 | sisian
# Processing Record 12 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 13 of Set 12 | ingenbohl
# Processing Record 14 of Set 12 | gazli
# Processing Record 15 of Set 12 | nome
# Processing Record 16 of Set 12 | nago
# Processing Record 17 of Set 12 | san francisco
# Processing Record 18 of Set 12 | kosovo polje
# Processing Record 19 of Set 12 | sambava
# Processing Record 20 of Set 12 | olafsvik
# Processing Record 21 of Set 12 | sivaki
# Processing Record 22 of Set 12 | baykit
# Processing Record 23 of Set 12 | beringovskiy
# Processing Record 24 of Set 12 | miguel hidalgo
# Processing Record 25 of Set 12 | tshikapa
# Processing Record 26 of Set 12 | lixourion
# Processing Record 27 of Set 12 | custoias
# Processing Record 28 of Set 12 | alta floresta
# Processing Record 29 of Set 12 | abu zabad
# Processing Record 30 of Set 12 | broome
# Processing Record 31 of Set 12 | necocli
# Processing Record 32 of Set 12 | acatzingo
# Processing Record 33 of Set 12 | bairiki
# Processing Record 34 of Set 12 | kungurtug
# Processing Record 35 of Set 12 | galgani
# City not found. Skipping...
# Processing Record 36 of Set 12 | ha giang
# Processing Record 37 of Set 12 | igarape-acu
# City not found. Skipping...
# Processing Record 38 of Set 12 | benguela
# Processing Record 39 of Set 12 | east hemet
# Processing Record 40 of Set 12 | port-cartier
# Processing Record 41 of Set 12 | conde
# Processing Record 42 of Set 12 | adjumani
# Processing Record 43 of Set 12 | canmore
# Processing Record 44 of Set 12 | inirida
# Processing Record 45 of Set 12 | salinopolis
# Processing Record 46 of Set 12 | auki
# Processing Record 47 of Set 12 | kincardine
# Processing Record 48 of Set 12 | bukachacha
# Processing Record 49 of Set 12 | taywarah
# Processing Record 50 of Set 12 | punta gorda
# Processing Record 1 of Set 13 | igrim
# Processing Record 2 of Set 13 | raudeberg
# Processing Record 3 of Set 13 | la libertad
# Processing Record 4 of Set 13 | along
# Processing Record 5 of Set 13 | armidale
# Processing Record 6 of Set 13 | gaoua
# Processing Record 7 of Set 13 | burica
# City not found. Skipping...
# Processing Record 8 of Set 13 | melo
# Processing Record 9 of Set 13 | vaitape
# Processing Record 10 of Set 13 | galesong
# Processing Record 11 of Set 13 | taoudenni
# Processing Record 12 of Set 13 | ukiah
# Processing Record 13 of Set 13 | udhampur
# Processing Record 14 of Set 13 | plouzane
# Processing Record 15 of Set 13 | lagos
# Processing Record 16 of Set 13 | aksarka
# Processing Record 17 of Set 13 | pemba
# Processing Record 18 of Set 13 | tire
# Processing Record 19 of Set 13 | oktyabrskiy
# Processing Record 20 of Set 13 | kurtamysh
# Processing Record 21 of Set 13 | vicuna
# Processing Record 22 of Set 13 | agua verde
# Processing Record 23 of Set 13 | nortelandia
# Processing Record 24 of Set 13 | adre
# Processing Record 25 of Set 13 | leiyang
# Processing Record 26 of Set 13 | kieta
# Processing Record 27 of Set 13 | salou
# Processing Record 28 of Set 13 | saskylakh
# Processing Record 29 of Set 13 | santa maria
# Processing Record 30 of Set 13 | snezhnogorsk
# Processing Record 31 of Set 13 | morden
# Processing Record 32 of Set 13 | asayita
# City not found. Skipping...
# Processing Record 33 of Set 13 | srednekolymsk
# Processing Record 34 of Set 13 | sakaiminato
# Processing Record 35 of Set 13 | realeza
# Processing Record 36 of Set 13 | bom jesus
# Processing Record 37 of Set 13 | aliaga
# Processing Record 38 of Set 13 | boysun
# Processing Record 39 of Set 13 | yeppoon
# Processing Record 40 of Set 13 | kawana waters
# City not found. Skipping...
# Processing Record 41 of Set 13 | ahipara
# Processing Record 42 of Set 13 | maua
# Processing Record 43 of Set 13 | pocoes
# Processing Record 44 of Set 13 | maumere
# Processing Record 45 of Set 13 | aswan
# Processing Record 46 of Set 13 | henties bay
# Processing Record 47 of Set 13 | ranong
# Processing Record 48 of Set 13 | owensboro
# Processing Record 49 of Set 13 | marsaxlokk
# Processing Record 50 of Set 13 | boyolangu
# Processing Record 1 of Set 14 | ngunguru
# Processing Record 2 of Set 14 | pokhara
# Processing Record 3 of Set 14 | tomatlan
# Processing Record 4 of Set 14 | bayevo
# Processing Record 5 of Set 14 | marathon
# Processing Record 6 of Set 14 | boa vista
# Processing Record 7 of Set 14 | jujuy
# City not found. Skipping...
# Processing Record 8 of Set 14 | mareeba
# Processing Record 9 of Set 14 | bathsheba
# Processing Record 10 of Set 14 | terrace
# Processing Record 11 of Set 14 | dongsheng
# Processing Record 12 of Set 14 | point pedro
# Processing Record 13 of Set 14 | jesus carranza
# Processing Record 14 of Set 14 | faratsiho
# Processing Record 15 of Set 14 | harrison
# Processing Record 16 of Set 14 | salisbury
# Processing Record 17 of Set 14 | rio cuarto
# Processing Record 18 of Set 14 | escarcega
# Processing Record 19 of Set 14 | mananjary
# Processing Record 20 of Set 14 | mykolayivka
# Processing Record 21 of Set 14 | hailar
# Processing Record 22 of Set 14 | ulaanbaatar
# Processing Record 23 of Set 14 | muisne
# Processing Record 24 of Set 14 | innisfail
# Processing Record 25 of Set 14 | sungairaya
# Processing Record 26 of Set 14 | evensk
# Processing Record 27 of Set 14 | ambulu
# Processing Record 28 of Set 14 | spirovo
# Processing Record 29 of Set 14 | thessalon
# Processing Record 30 of Set 14 | buta
# Processing Record 31 of Set 14 | huarmey
# Processing Record 32 of Set 14 | bujaru
# Processing Record 33 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 34 of Set 14 | murici
# Processing Record 35 of Set 14 | tupanatinga
# Processing Record 36 of Set 14 | buala
# Processing Record 37 of Set 14 | killarney
# Processing Record 38 of Set 14 | cavalcante
# Processing Record 39 of Set 14 | christchurch
# Processing Record 40 of Set 14 | sakakah
# Processing Record 41 of Set 14 | vilyuysk
# Processing Record 42 of Set 14 | alquizar
# Processing Record 43 of Set 14 | shache
# Processing Record 44 of Set 14 | inta
# Processing Record 45 of Set 14 | mokhsogollokh
# Processing Record 46 of Set 14 | surt
# Processing Record 47 of Set 14 | leningradskiy
# Processing Record 48 of Set 14 | torres
# Processing Record 49 of Set 14 | maine-soroa
# Processing Record 50 of Set 14 | linhares
# Processing Record 1 of Set 15 | paita
# Processing Record 2 of Set 15 | flinders
# Processing Record 3 of Set 15 | fort-shevchenko
# Processing Record 4 of Set 15 | aktas
# Processing Record 5 of Set 15 | alotau
# City not found. Skipping...
# Processing Record 6 of Set 15 | kendari
# Processing Record 7 of Set 15 | gao
# Processing Record 8 of Set 15 | placido de castro
# Processing Record 9 of Set 15 | safwah
# City not found. Skipping...
# Processing Record 10 of Set 15 | araguatins
# City not found. Skipping...
# Processing Record 11 of Set 15 | campo maior
# Processing Record 12 of Set 15 | xuddur
# Processing Record 13 of Set 15 | krasnoarmeyskiy
# Processing Record 14 of Set 15 | conroe
# Processing Record 15 of Set 15 | laurinburg
# Processing Record 16 of Set 15 | crasna
# Processing Record 17 of Set 15 | coruripe
# Processing Record 18 of Set 15 | tulun
# Processing Record 19 of Set 15 | mazagao
# Processing Record 20 of Set 15 | alofi
# Processing Record 21 of Set 15 | menongue
# Processing Record 22 of Set 15 | malartic
# Processing Record 23 of Set 15 | ipixuna
# Processing Record 24 of Set 15 | tabou
# Processing Record 25 of Set 15 | bilibino
# Processing Record 26 of Set 15 | phumi samraong
# City not found. Skipping...
# Processing Record 27 of Set 15 | safranbolu
# Processing Record 28 of Set 15 | dakar
# Processing Record 29 of Set 15 | pilar
# Processing Record 30 of Set 15 | podyuga
# Processing Record 31 of Set 15 | bafq
# Processing Record 32 of Set 15 | susehri
# Processing Record 33 of Set 15 | terebovlya
# Processing Record 34 of Set 15 | umm kaddadah
# Processing Record 35 of Set 15 | granville
# Processing Record 36 of Set 15 | guajara
# Processing Record 37 of Set 15 | punto fijo
# Processing Record 38 of Set 15 | machali
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 678

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Cape Town      ZA -33.9258   18.4232     69.89        54           0
# 1     Upernavik      GL  72.7868  -56.1549     37.85        84           1
# 2       Bogdana      RO  43.9333   25.0833     67.01        59          87
# 3         Acari      PE -15.4311  -74.6158     73.62        53          34
# 4        Hirara      JP  24.8000  125.2833     80.15        81         100
# 5     Aginskoye      RU  51.1000  114.5300     54.10        54           9
# 6        Padang      ID  -0.9492  100.3543     77.05        87          85
# 7  Longyearbyen      SJ  78.2186   15.6401     35.44        80          75
# 8  Konigswinter      DE  50.6833    7.1833     77.43        60          55
# 9       Rikitea      PF -23.1203 -134.9692     76.51        83          99
#
#    Wind Speed   Current Description
# 0        1.99             clear sky
# 1        1.92             clear sky
# 2        3.96  heavy intensity rain
# 3        4.68      scattered clouds
# 4       16.20       overcast clouds
# 5        2.73             clear sky
# 6        2.64       overcast clouds
# 7        9.22         broken clouds
# 8        5.93         broken clouds
# 9       19.48            light rain

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
