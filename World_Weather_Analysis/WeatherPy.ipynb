# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

#This zip objects packs each pair of lats and lngs having the same index in their respective array into a tuple

# %%
#Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
#Use the citipy module to determine city based on latitude and longitude
from citipy import citipy

# %%
#Create a list for holding the cities
cities = []

#Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
#Print the city count to confirm sufficient count
len(cities)
# Out:
# 577

# %%
#Import dependencies
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create an empty list to hold the weather data
city_data = []

#Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters
record_count = 1
set_count = 1

#Loop through all the cities in our list
for i, city in enumerate(cities):
    #Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    #Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    #Add 1 toS the record count
    record_count += 1
    ### Code Breakdown ###
    #Create a for loop with the enumerate() method and reference the index and the city in the list
    #Check if the remainder of the index divided by 50 is equal to zero, AND if the index is greater than or equal to 50,
    # using a conditional statement.
    #Create a URL endpoint in the conditional statement. However, we are removing blank spaces in the city name and 
    # concatenating the city name using city.replace(" ","+"). This will find the corresponding weather data for the city
    # instead of finding the weather data for the first part of the city name.
    #Add a print statement that tells the record count, set count, and the city that is being processed
    #Then add 1 to the record count before the next city is processed

#Run an API request for each of the cites 
    try:
        #Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        #Parse out the needed data
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        #Convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        #Append the city information into city_data list
        city_data.append({'City': city.title(),
                          'Lat': city_lat, 
                          'Lng': city_lng, 
                          'Max Temp': city_max_temp, 
                          'Humidity': city_humidity, 
                          'Cloudiness': city_clouds, 
                          'Wind Speed': city_wind, 
                          'Country': city_country, 
                          'Date': city_date})
#If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

#Indicate that the Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

    ### Code Breakdown ###
    #Parse the JSON file for the current city.
    #If there is weather data for the city, the metrics are retrieved.
    #The cities list is appended with a dictionary for that city, where the key value pairs 
    # are the values from the parameters.
    #Add the try and except block.
    #Add a pass statement to handle all errors encountered and to allow the program to continue.
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kavieng
# Processing Record 2 of Set 1 | klaksvik
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | fallon
# Processing Record 6 of Set 1 | togur
# Processing Record 7 of Set 1 | walvis bay
# Processing Record 8 of Set 1 | maryville
# Processing Record 9 of Set 1 | provideniya
# Processing Record 10 of Set 1 | hervey bay
# Processing Record 11 of Set 1 | hasaki
# Processing Record 12 of Set 1 | kodiak
# Processing Record 13 of Set 1 | esperance
# Processing Record 14 of Set 1 | mar del plata
# Processing Record 15 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | kruisfontein
# Processing Record 19 of Set 1 | chokurdakh
# Processing Record 20 of Set 1 | mazatlan
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | nabire
# Processing Record 23 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 1 | birjand
# Processing Record 25 of Set 1 | tazovskiy
# Processing Record 26 of Set 1 | clyde river
# Processing Record 27 of Set 1 | zatoka
# Processing Record 28 of Set 1 | saskylakh
# Processing Record 29 of Set 1 | batagay
# Processing Record 30 of Set 1 | khatanga
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | dikson
# Processing Record 33 of Set 1 | lebu
# Processing Record 34 of Set 1 | khani
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | hobart
# Processing Record 37 of Set 1 | seymchan
# Processing Record 38 of Set 1 | pevek
# Processing Record 39 of Set 1 | pontianak
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 1 | mikhaylovka
# Processing Record 42 of Set 1 | bethel
# Processing Record 43 of Set 1 | huilong
# Processing Record 44 of Set 1 | solnechnyy
# Processing Record 45 of Set 1 | mataura
# Processing Record 46 of Set 1 | ayer itam
# City not found. Skipping...
# Processing Record 47 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 1 | longyearbyen
# Processing Record 49 of Set 1 | norman wells
# Processing Record 50 of Set 1 | butaritari
# Processing Record 1 of Set 2 | cape town
# Processing Record 2 of Set 2 | cidreira
# Processing Record 3 of Set 2 | tasiilaq
# Processing Record 4 of Set 2 | castro
# Processing Record 5 of Set 2 | alofi
# Processing Record 6 of Set 2 | hovd
# Processing Record 7 of Set 2 | mogadishu
# Processing Record 8 of Set 2 | hilo
# Processing Record 9 of Set 2 | punta arenas
# Processing Record 10 of Set 2 | new norfolk
# Processing Record 11 of Set 2 | weligama
# Processing Record 12 of Set 2 | byron bay
# Processing Record 13 of Set 2 | kandrian
# Processing Record 14 of Set 2 | tiksi
# Processing Record 15 of Set 2 | astana
# Processing Record 16 of Set 2 | albany
# Processing Record 17 of Set 2 | quimper
# Processing Record 18 of Set 2 | port elizabeth
# Processing Record 19 of Set 2 | airai
# Processing Record 20 of Set 2 | kapaa
# Processing Record 21 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 2 | jamestown
# Processing Record 23 of Set 2 | isabela
# Processing Record 24 of Set 2 | moree
# Processing Record 25 of Set 2 | chapais
# Processing Record 26 of Set 2 | vila
# Processing Record 27 of Set 2 | saint-philippe
# Processing Record 28 of Set 2 | charters towers
# Processing Record 29 of Set 2 | pecos
# Processing Record 30 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 31 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 2 | tome-acu
# City not found. Skipping...
# Processing Record 33 of Set 2 | kaseda
# Processing Record 34 of Set 2 | ajaccio
# Processing Record 35 of Set 2 | pacific grove
# Processing Record 36 of Set 2 | guerrero negro
# Processing Record 37 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 2 | willmar
# Processing Record 39 of Set 2 | palu
# Processing Record 40 of Set 2 | rabo de peixe
# Processing Record 41 of Set 2 | garmsar
# Processing Record 42 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 2 | kaitangata
# Processing Record 44 of Set 2 | georgetown
# Processing Record 45 of Set 2 | novoorsk
# Processing Record 46 of Set 2 | ribas do rio pardo
# Processing Record 47 of Set 2 | buala
# Processing Record 48 of Set 2 | sao borja
# Processing Record 49 of Set 2 | gat
# Processing Record 50 of Set 2 | puerto ayora
# Processing Record 1 of Set 3 | banyo
# Processing Record 2 of Set 3 | san patricio
# Processing Record 3 of Set 3 | deputatskiy
# Processing Record 4 of Set 3 | ancud
# Processing Record 5 of Set 3 | ilulissat
# Processing Record 6 of Set 3 | mende
# Processing Record 7 of Set 3 | alice springs
# Processing Record 8 of Set 3 | grootfontein
# Processing Record 9 of Set 3 | port alfred
# Processing Record 10 of Set 3 | cuamba
# Processing Record 11 of Set 3 | souillac
# Processing Record 12 of Set 3 | cabo san lucas
# Processing Record 13 of Set 3 | santa isabel
# Processing Record 14 of Set 3 | barabai
# Processing Record 15 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 3 | iqaluit
# Processing Record 17 of Set 3 | avarua
# Processing Record 18 of Set 3 | opuwo
# Processing Record 19 of Set 3 | pacifica
# Processing Record 20 of Set 3 | thompson
# Processing Record 21 of Set 3 | saldanha
# Processing Record 22 of Set 3 | emerald
# Processing Record 23 of Set 3 | qaanaaq
# Processing Record 24 of Set 3 | nikolskoye
# Processing Record 25 of Set 3 | santa marta
# Processing Record 26 of Set 3 | kahului
# Processing Record 27 of Set 3 | asayita
# City not found. Skipping...
# Processing Record 28 of Set 3 | kaeo
# Processing Record 29 of Set 3 | namatanai
# Processing Record 30 of Set 3 | tigil
# Processing Record 31 of Set 3 | tabuk
# Processing Record 32 of Set 3 | banda aceh
# Processing Record 33 of Set 3 | san pedro
# Processing Record 34 of Set 3 | cabedelo
# Processing Record 35 of Set 3 | hithadhoo
# Processing Record 36 of Set 3 | colac
# Processing Record 37 of Set 3 | taksimo
# Processing Record 38 of Set 3 | bluff
# Processing Record 39 of Set 3 | tual
# Processing Record 40 of Set 3 | barrow
# Processing Record 41 of Set 3 | kaka
# Processing Record 42 of Set 3 | camana
# Processing Record 43 of Set 3 | naze
# Processing Record 44 of Set 3 | tura
# Processing Record 45 of Set 3 | cherskiy
# Processing Record 46 of Set 3 | porto alegre
# Processing Record 47 of Set 3 | opelousas
# Processing Record 48 of Set 3 | vao
# Processing Record 49 of Set 3 | harper
# Processing Record 50 of Set 3 | padang
# Processing Record 1 of Set 4 | kotelnikovo
# Processing Record 2 of Set 4 | bredasdorp
# Processing Record 3 of Set 4 | benton harbor
# Processing Record 4 of Set 4 | kieta
# Processing Record 5 of Set 4 | lorengau
# Processing Record 6 of Set 4 | delemont
# Processing Record 7 of Set 4 | husavik
# Processing Record 8 of Set 4 | novobiryusinskiy
# Processing Record 9 of Set 4 | la ronge
# Processing Record 10 of Set 4 | havelock
# Processing Record 11 of Set 4 | upernavik
# Processing Record 12 of Set 4 | novita
# Processing Record 13 of Set 4 | samarai
# Processing Record 14 of Set 4 | roald
# Processing Record 15 of Set 4 | akyab
# Processing Record 16 of Set 4 | jibuti
# Processing Record 17 of Set 4 | oyama
# Processing Record 18 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 19 of Set 4 | saryg-sep
# Processing Record 20 of Set 4 | kharhial
# Processing Record 21 of Set 4 | flin flon
# Processing Record 22 of Set 4 | pisco
# Processing Record 23 of Set 4 | calatayud
# Processing Record 24 of Set 4 | pekan
# Processing Record 25 of Set 4 | wagga wagga
# Processing Record 26 of Set 4 | constitucion
# Processing Record 27 of Set 4 | narsaq
# Processing Record 28 of Set 4 | penzance
# Processing Record 29 of Set 4 | makakilo city
# Processing Record 30 of Set 4 | fare
# Processing Record 31 of Set 4 | sept-iles
# Processing Record 32 of Set 4 | joshimath
# Processing Record 33 of Set 4 | mayo
# Processing Record 34 of Set 4 | arraial do cabo
# Processing Record 35 of Set 4 | vanimo
# Processing Record 36 of Set 4 | pitimbu
# Processing Record 37 of Set 4 | salalah
# Processing Record 38 of Set 4 | krasnoselkup
# Processing Record 39 of Set 4 | hamilton
# Processing Record 40 of Set 4 | namibe
# Processing Record 41 of Set 4 | luderitz
# Processing Record 42 of Set 4 | nesna
# Processing Record 43 of Set 4 | sardarshahr
# Processing Record 44 of Set 4 | agalatovo
# Processing Record 45 of Set 4 | sanlucar de barrameda
# Processing Record 46 of Set 4 | severo-kurilsk
# Processing Record 47 of Set 4 | palauig
# Processing Record 48 of Set 4 | wiwili
# Processing Record 49 of Set 4 | mahebourg
# Processing Record 50 of Set 4 | sampit
# Processing Record 1 of Set 5 | pangnirtung
# Processing Record 2 of Set 5 | bejucal
# Processing Record 3 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 5 | chiredzi
# Processing Record 5 of Set 5 | brigantine
# Processing Record 6 of Set 5 | dukat
# Processing Record 7 of Set 5 | amahai
# Processing Record 8 of Set 5 | oussouye
# Processing Record 9 of Set 5 | lulea
# Processing Record 10 of Set 5 | lompoc
# Processing Record 11 of Set 5 | scottsburgh
# City not found. Skipping...
# Processing Record 12 of Set 5 | kamaishi
# Processing Record 13 of Set 5 | chuy
# Processing Record 14 of Set 5 | telde
# Processing Record 15 of Set 5 | kimbe
# Processing Record 16 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 5 | victoria
# Processing Record 18 of Set 5 | oster
# Processing Record 19 of Set 5 | ayna
# Processing Record 20 of Set 5 | aasiaat
# Processing Record 21 of Set 5 | tuktoyaktuk
# Processing Record 22 of Set 5 | pimentel
# Processing Record 23 of Set 5 | carnarvon
# Processing Record 24 of Set 5 | nicoya
# Processing Record 25 of Set 5 | vestmanna
# Processing Record 26 of Set 5 | meulaboh
# Processing Record 27 of Set 5 | jalu
# Processing Record 28 of Set 5 | saint anthony
# Processing Record 29 of Set 5 | cranbrook
# Processing Record 30 of Set 5 | matias romero
# Processing Record 31 of Set 5 | half moon bay
# Processing Record 32 of Set 5 | vestmannaeyjar
# Processing Record 33 of Set 5 | barentu
# Processing Record 34 of Set 5 | inverell
# Processing Record 35 of Set 5 | eenhana
# Processing Record 36 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 37 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 5 | bambous virieux
# Processing Record 39 of Set 5 | masvingo
# Processing Record 40 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 41 of Set 5 | avera
# Processing Record 42 of Set 5 | igrim
# Processing Record 43 of Set 5 | kloulklubed
# Processing Record 44 of Set 5 | faanui
# Processing Record 45 of Set 5 | marsa matruh
# Processing Record 46 of Set 5 | rakhya
# City not found. Skipping...
# Processing Record 47 of Set 5 | bandarbeyla
# Processing Record 48 of Set 5 | mendahara
# City not found. Skipping...
# Processing Record 49 of Set 5 | katobu
# Processing Record 50 of Set 5 | jimenez
# Processing Record 1 of Set 6 | sakakah
# Processing Record 2 of Set 6 | zambezi
# Processing Record 3 of Set 6 | pachino
# Processing Record 4 of Set 6 | nanortalik
# Processing Record 5 of Set 6 | port moresby
# Processing Record 6 of Set 6 | fortuna
# Processing Record 7 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 6 | el faiyum
# City not found. Skipping...
# Processing Record 9 of Set 6 | hobyo
# Processing Record 10 of Set 6 | faya
# Processing Record 11 of Set 6 | lemesos
# City not found. Skipping...
# Processing Record 12 of Set 6 | sungaipenuh
# Processing Record 13 of Set 6 | pasighat
# Processing Record 14 of Set 6 | xining
# Processing Record 15 of Set 6 | san cristobal
# Processing Record 16 of Set 6 | ribeira grande
# Processing Record 17 of Set 6 | ust-kuyga
# Processing Record 18 of Set 6 | wanning
# Processing Record 19 of Set 6 | mattru
# Processing Record 20 of Set 6 | port hedland
# Processing Record 21 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 6 | libreville
# Processing Record 23 of Set 6 | winneba
# Processing Record 24 of Set 6 | nhulunbuy
# Processing Record 25 of Set 6 | makungu
# Processing Record 26 of Set 6 | mosquera
# Processing Record 27 of Set 6 | grindavik
# Processing Record 28 of Set 6 | korla
# Processing Record 29 of Set 6 | lethem
# Processing Record 30 of Set 6 | east london
# Processing Record 31 of Set 6 | balikpapan
# Processing Record 32 of Set 6 | garowe
# Processing Record 33 of Set 6 | likasi
# Processing Record 34 of Set 6 | fredericton
# Processing Record 35 of Set 6 | mareeba
# Processing Record 36 of Set 6 | muriti
# Processing Record 37 of Set 6 | mossendjo
# Processing Record 38 of Set 6 | churapcha
# Processing Record 39 of Set 6 | rendsburg
# Processing Record 40 of Set 6 | mandera
# Processing Record 41 of Set 6 | vryheid
# Processing Record 42 of Set 6 | biu
# Processing Record 43 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 44 of Set 6 | saint-pierre
# Processing Record 45 of Set 6 | port blair
# Processing Record 46 of Set 6 | talnakh
# Processing Record 47 of Set 6 | torbay
# Processing Record 48 of Set 6 | kut chap
# Processing Record 49 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 6 | bathsheba
# Processing Record 1 of Set 7 | rudnogorsk
# Processing Record 2 of Set 7 | ketchikan
# Processing Record 3 of Set 7 | saint-ambroise
# Processing Record 4 of Set 7 | nara
# Processing Record 5 of Set 7 | tranas
# Processing Record 6 of Set 7 | tonj
# Processing Record 7 of Set 7 | basugaon
# Processing Record 8 of Set 7 | qaqortoq
# Processing Record 9 of Set 7 | abong mbang
# Processing Record 10 of Set 7 | rundu
# Processing Record 11 of Set 7 | saint-francois
# Processing Record 12 of Set 7 | phra phutthabat
# Processing Record 13 of Set 7 | znamenskoye
# Processing Record 14 of Set 7 | madaoua
# Processing Record 15 of Set 7 | ambon
# Processing Record 16 of Set 7 | katsuura
# Processing Record 17 of Set 7 | manokwari
# Processing Record 18 of Set 7 | raudeberg
# Processing Record 19 of Set 7 | bontang
# Processing Record 20 of Set 7 | akureyri
# Processing Record 21 of Set 7 | eyrarbakki
# Processing Record 22 of Set 7 | vardo
# Processing Record 23 of Set 7 | nelson bay
# Processing Record 24 of Set 7 | lucea
# Processing Record 25 of Set 7 | luwuk
# Processing Record 26 of Set 7 | rocha
# Processing Record 27 of Set 7 | zhirnovsk
# Processing Record 28 of Set 7 | mount gambier
# Processing Record 29 of Set 7 | bambanglipuro
# Processing Record 30 of Set 7 | zhumadian
# Processing Record 31 of Set 7 | espoo
# Processing Record 32 of Set 7 | quelimane
# Processing Record 33 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 7 | fairbanks
# Processing Record 35 of Set 7 | trairi
# Processing Record 36 of Set 7 | sao filipe
# Processing Record 37 of Set 7 | dawlatabad
# Processing Record 38 of Set 7 | krasnovishersk
# Processing Record 39 of Set 7 | baker city
# Processing Record 40 of Set 7 | launceston
# Processing Record 41 of Set 7 | lazaro cardenas
# Processing Record 42 of Set 7 | grand gaube
# Processing Record 43 of Set 7 | of
# City not found. Skipping...
# Processing Record 44 of Set 7 | puqi
# Processing Record 45 of Set 7 | portland
# Processing Record 46 of Set 7 | lagoa
# Processing Record 47 of Set 7 | bitung
# Processing Record 48 of Set 7 | senanga
# Processing Record 49 of Set 7 | shunyi
# Processing Record 50 of Set 7 | erhlin
# City not found. Skipping...
# Processing Record 1 of Set 8 | petropavlovskoye
# Processing Record 2 of Set 8 | goderich
# Processing Record 3 of Set 8 | marzuq
# Processing Record 4 of Set 8 | rumphi
# Processing Record 5 of Set 8 | inhambane
# Processing Record 6 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 7 of Set 8 | jawar
# Processing Record 8 of Set 8 | nador
# Processing Record 9 of Set 8 | aklavik
# Processing Record 10 of Set 8 | tucuman
# Processing Record 11 of Set 8 | rosbach
# Processing Record 12 of Set 8 | naica
# Processing Record 13 of Set 8 | arkadelphia
# Processing Record 14 of Set 8 | cochrane
# Processing Record 15 of Set 8 | darnah
# Processing Record 16 of Set 8 | mezhdurechensk
# Processing Record 17 of Set 8 | takaungu
# Processing Record 18 of Set 8 | trinidad
# Processing Record 19 of Set 8 | don benito
# Processing Record 20 of Set 8 | buchanan
# Processing Record 21 of Set 8 | tarauaca
# Processing Record 22 of Set 8 | miri
# Processing Record 23 of Set 8 | cururupu
# Processing Record 24 of Set 8 | berlevag
# Processing Record 25 of Set 8 | bayan
# Processing Record 26 of Set 8 | sheridan
# Processing Record 27 of Set 8 | baghdad
# Processing Record 28 of Set 8 | yenagoa
# Processing Record 29 of Set 8 | lasa
# Processing Record 30 of Set 8 | moengo
# Processing Record 31 of Set 8 | vila do maio
# Processing Record 32 of Set 8 | tungor
# Processing Record 33 of Set 8 | shingu
# Processing Record 34 of Set 8 | olinda
# Processing Record 35 of Set 8 | richard toll
# City not found. Skipping...
# Processing Record 36 of Set 8 | sweetwater
# Processing Record 37 of Set 8 | codrington
# Processing Record 38 of Set 8 | suriapet
# Processing Record 39 of Set 8 | port lincoln
# Processing Record 40 of Set 8 | bud
# Processing Record 41 of Set 8 | teya
# Processing Record 42 of Set 8 | turukhansk
# Processing Record 43 of Set 8 | coihaique
# Processing Record 44 of Set 8 | sola
# Processing Record 45 of Set 8 | tsaratanana
# Processing Record 46 of Set 8 | satun
# Processing Record 47 of Set 8 | shimoda
# Processing Record 48 of Set 8 | falam
# Processing Record 49 of Set 8 | sinnamary
# Processing Record 50 of Set 8 | kerrville
# Processing Record 1 of Set 9 | navoi
# Processing Record 2 of Set 9 | geraldton
# Processing Record 3 of Set 9 | gobabis
# Processing Record 4 of Set 9 | vila franca do campo
# Processing Record 5 of Set 9 | beaverton
# Processing Record 6 of Set 9 | sakaiminato
# Processing Record 7 of Set 9 | sitka
# Processing Record 8 of Set 9 | pemba
# Processing Record 9 of Set 9 | juifang
# City not found. Skipping...
# Processing Record 10 of Set 9 | pangai
# Processing Record 11 of Set 9 | tautira
# Processing Record 12 of Set 9 | cockburn town
# Processing Record 13 of Set 9 | nemuro
# Processing Record 14 of Set 9 | dubbo
# Processing Record 15 of Set 9 | shache
# Processing Record 16 of Set 9 | nisia floresta
# Processing Record 17 of Set 9 | gravdal
# Processing Record 18 of Set 9 | irpa irpa
# Processing Record 19 of Set 9 | wukari
# Processing Record 20 of Set 9 | sioux lookout
# Processing Record 21 of Set 9 | impfondo
# Processing Record 22 of Set 9 | heihe
# Processing Record 23 of Set 9 | chinhoyi
# Processing Record 24 of Set 9 | richards bay
# Processing Record 25 of Set 9 | sesheke
# Processing Record 26 of Set 9 | nevers
# Processing Record 27 of Set 9 | linkou
# Processing Record 28 of Set 9 | juneau
# Processing Record 29 of Set 9 | dayong
# Processing Record 30 of Set 9 | berbera
# Processing Record 31 of Set 9 | angoche
# Processing Record 32 of Set 9 | ulladulla
# Processing Record 33 of Set 9 | karratha
# Processing Record 34 of Set 9 | rawson
# Processing Record 35 of Set 9 | yeniseysk
# Processing Record 36 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 37 of Set 9 | bilibino
# Processing Record 38 of Set 9 | uspenka
# Processing Record 39 of Set 9 | leningradskiy
# Processing Record 40 of Set 9 | daye
# Processing Record 41 of Set 9 | paraiso
# Processing Record 42 of Set 9 | san alberto
# Processing Record 43 of Set 9 | mandalgovi
# Processing Record 44 of Set 9 | mount isa
# Processing Record 45 of Set 9 | paracuru
# Processing Record 46 of Set 9 | ambilobe
# Processing Record 47 of Set 9 | flinders
# Processing Record 48 of Set 9 | hirara
# Processing Record 49 of Set 9 | muzaffargarh
# Processing Record 50 of Set 9 | saint george
# Processing Record 1 of Set 10 | sitio novo do tocantins
# Processing Record 2 of Set 10 | sur
# Processing Record 3 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 4 of Set 10 | new castle
# Processing Record 5 of Set 10 | komsomolskiy
# Processing Record 6 of Set 10 | bossembele
# City not found. Skipping...
# Processing Record 7 of Set 10 | hay river
# Processing Record 8 of Set 10 | shatrovo
# Processing Record 9 of Set 10 | tuatapere
# Processing Record 10 of Set 10 | sebeta
# Processing Record 11 of Set 10 | tinyahuarco
# Processing Record 12 of Set 10 | aykino
# Processing Record 13 of Set 10 | kavaratti
# Processing Record 14 of Set 10 | santa maria
# Processing Record 15 of Set 10 | morant bay
# Processing Record 16 of Set 10 | bengkulu
# Processing Record 17 of Set 10 | san juan del sur
# Processing Record 18 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 19 of Set 10 | roma
# Processing Record 20 of Set 10 | akhmim
# Processing Record 21 of Set 10 | kodinsk
# Processing Record 22 of Set 10 | bridlington
# Processing Record 23 of Set 10 | isangel
# Processing Record 24 of Set 10 | moron de la frontera
# Processing Record 25 of Set 10 | amethi
# Processing Record 26 of Set 10 | guangyuan
# Processing Record 27 of Set 10 | eskisehir
# Processing Record 28 of Set 10 | severnyy
# Processing Record 29 of Set 10 | antofagasta
# Processing Record 30 of Set 10 | maroantsetra
# Processing Record 31 of Set 10 | aitape
# Processing Record 32 of Set 10 | helong
# Processing Record 33 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 34 of Set 10 | sabha
# Processing Record 35 of Set 10 | coquimbo
# Processing Record 36 of Set 10 | ponta do sol
# Processing Record 37 of Set 10 | baykit
# Processing Record 38 of Set 10 | muzhi
# Processing Record 39 of Set 10 | yerbogachen
# Processing Record 40 of Set 10 | puerto leguizamo
# Processing Record 41 of Set 10 | progreso
# Processing Record 42 of Set 10 | ahipara
# Processing Record 43 of Set 10 | nola
# Processing Record 44 of Set 10 | dunedin
# Processing Record 45 of Set 10 | bonfim
# Processing Record 46 of Set 10 | mbigou
# Processing Record 47 of Set 10 | andenes
# Processing Record 48 of Set 10 | mbini
# Processing Record 49 of Set 10 | cozumel
# Processing Record 50 of Set 10 | salinopolis
# Processing Record 1 of Set 11 | margate
# Processing Record 2 of Set 11 | peleduy
# Processing Record 3 of Set 11 | bijie
# Processing Record 4 of Set 11 | ossora
# Processing Record 5 of Set 11 | hualmay
# Processing Record 6 of Set 11 | caravelas
# Processing Record 7 of Set 11 | muros
# Processing Record 8 of Set 11 | san felipe
# Processing Record 9 of Set 11 | kargasok
# Processing Record 10 of Set 11 | elsfleth
# Processing Record 11 of Set 11 | noumea
# Processing Record 12 of Set 11 | vieste
# Processing Record 13 of Set 11 | anadyr
# Processing Record 14 of Set 11 | nome
# Processing Record 15 of Set 11 | rumboci
# Processing Record 16 of Set 11 | merauke
# Processing Record 17 of Set 11 | pokhara
# Processing Record 18 of Set 11 | kristiansund
# Processing Record 19 of Set 11 | chimbote
# Processing Record 20 of Set 11 | chicama
# Processing Record 21 of Set 11 | tevriz
# Processing Record 22 of Set 11 | saint marys
# Processing Record 23 of Set 11 | tapaua
# City not found. Skipping...
# Processing Record 24 of Set 11 | ulaanbaatar
# Processing Record 25 of Set 11 | singleton
# Processing Record 26 of Set 11 | mosetse
# Processing Record 27 of Set 11 | dalbandin
# Processing Record 28 of Set 11 | auki
# Processing Record 29 of Set 11 | calvinia
# Processing Record 30 of Set 11 | kirakira
# Processing Record 31 of Set 11 | shitanjing
# Processing Record 32 of Set 11 | hearst
# Processing Record 33 of Set 11 | aksu
# Processing Record 34 of Set 11 | calama
# Processing Record 35 of Set 11 | marolambo
# Processing Record 36 of Set 11 | awash
# Processing Record 37 of Set 11 | kenai
# Processing Record 38 of Set 11 | navsari
# Processing Record 39 of Set 11 | manado
# Processing Record 40 of Set 11 | athabasca
# Processing Record 41 of Set 11 | nauta
# Processing Record 42 of Set 11 | ponta delgada
# Processing Record 43 of Set 11 | uray
# Processing Record 44 of Set 11 | lavrentiya
# Processing Record 45 of Set 11 | fort morgan
# Processing Record 46 of Set 11 | potosi
# Processing Record 47 of Set 11 | port hardy
# Processing Record 48 of Set 11 | zyryanovskiy
# City not found. Skipping...
# Processing Record 49 of Set 11 | matagami
# Processing Record 50 of Set 11 | ayan
# Processing Record 1 of Set 12 | port-de-paix
# City not found. Skipping...
# Processing Record 2 of Set 12 | bonito
# Processing Record 3 of Set 12 | haines junction
# Processing Record 4 of Set 12 | aseri
# Processing Record 5 of Set 12 | sayanskiy
# City not found. Skipping...
# Processing Record 6 of Set 12 | ahuimanu
# Processing Record 7 of Set 12 | umm lajj
# Processing Record 8 of Set 12 | lata
# Processing Record 9 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 10 of Set 12 | turtkul
# City not found. Skipping...
# Processing Record 11 of Set 12 | morondava
# Processing Record 12 of Set 12 | luxor
# Processing Record 13 of Set 12 | gaeta
# Processing Record 14 of Set 12 | shasta lake
# Processing Record 15 of Set 12 | dingle
# Processing Record 16 of Set 12 | halifax
# Processing Record 17 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 12 | pareora
# Processing Record 19 of Set 12 | los llanos de aridane
# Processing Record 20 of Set 12 | kurayoshi
# Processing Record 21 of Set 12 | maragogi
# Processing Record 22 of Set 12 | nago
# Processing Record 23 of Set 12 | oranjemund
# Processing Record 24 of Set 12 | amuntai
# Processing Record 25 of Set 12 | puerto maldonado
# Processing Record 26 of Set 12 | atocha
# Processing Record 27 of Set 12 | bjornevatn
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 531

# %%
#Convert the array of dictionaries into a Pandas data frame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Kavieng  -2.5744  150.7967     81.30        82          99       11.99
# 1     Klaksvik  62.2266   -6.5890     50.92        97          49       15.59
# 2      Ushuaia -54.8000  -68.3000     44.22        81          75        3.44
# 3      Rikitea -23.1203 -134.9692     76.48        84          98       19.84
# 4       Fallon  39.4735 -118.7774     60.58        25           1        3.44
# 5        Togur  58.3631   82.8265     41.81        72          98       17.09
# 6   Walvis Bay -22.9575   14.5053     63.09        56           0       12.46
# 7    Maryville  35.7565  -83.9705     79.16        89          98        1.01
# 8  Provideniya  64.3833 -173.3000     34.59        87          12        3.02
# 9   Hervey Bay -25.2986  152.8535     70.03        88         100        5.99
#
#   Country                 Date
# 0      PG  2021-06-08 14:05:51
# 1      FO  2021-06-08 14:05:51
# 2      AR  2021-06-08 14:05:51
# 3      PF  2021-06-08 14:05:51
# 4      US  2021-06-08 14:05:52
# 5      RU  2021-06-08 14:05:52
# 6      NA  2021-06-08 14:05:52
# 7      US  2021-06-08 14:04:23
# 8      RU  2021-06-08 14:05:52
# 9      AU  2021-06-08 14:05:53

# %%
#Reorder the columns
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0      Kavieng      PG  2021-06-08 14:05:51  -2.5744  150.7967     81.30
# 1     Klaksvik      FO  2021-06-08 14:05:51  62.2266   -6.5890     50.92
# 2      Ushuaia      AR  2021-06-08 14:05:51 -54.8000  -68.3000     44.22
# 3      Rikitea      PF  2021-06-08 14:05:51 -23.1203 -134.9692     76.48
# 4       Fallon      US  2021-06-08 14:05:52  39.4735 -118.7774     60.58
# 5        Togur      RU  2021-06-08 14:05:52  58.3631   82.8265     41.81
# 6   Walvis Bay      NA  2021-06-08 14:05:52 -22.9575   14.5053     63.09
# 7    Maryville      US  2021-06-08 14:04:23  35.7565  -83.9705     79.16
# 8  Provideniya      RU  2021-06-08 14:05:52  64.3833 -173.3000     34.59
# 9   Hervey Bay      AU  2021-06-08 14:05:53 -25.2986  152.8535     70.03
#
#    Humidity  Cloudiness  Wind Speed
# 0        82          99       11.99
# 1        97          49       15.59
# 2        81          75        3.44
# 3        84          98       19.84
# 4        25           1        3.44
# 5        72          98       17.09
# 6        56           0       12.46
# 7        89          98        1.01
# 8        87          12        3.02
# 9        88         100        5.99

# %%
#Create the output file (CSV)
output_data_file = "weather_data/cities.csv"

#Export the city_data into a CSV
city_data_df.to_csv(output_data_file, index_label='City_ID')

# %%
#Extract relevant fields from the data frame for plotting
lats = city_data_df['Lat']
max_temps = city_data_df['Max Temp']
humidity = city_data_df['Humidity']
cloudiness = city_data_df['Cloudiness']
wind_speed = city_data_df['Wind Speed']

# %%
#Import time module
import time

#Build the scatter plot for latitude vs. max temperature
plt.scatter(lats, 
            max_temps, 
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

#Incorporate the other graph properties
plt.title(f'City Latitude vs. Max Temperature '+ time.strftime('%x'))
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.grid(True)

#Save the figure
plt.savefig('weather_data/Fig1.png')

#Show plot
plt.show()

# %%
#Build the scatter plots for latitude vs. humidity
plt.scatter(lats, 
            humidity, 
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

#Incorporate the other graph properties
plt.title(f'City Latitude vs. Humidity '+ time.strftime('%x'))
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.grid(True)

#Save the figure
plt.savefig('weather_data/Fig2.png')

#Show plot
plt.show()

# %%
#Build the scatter plot for latitude vs. cloudiness
plt.scatter(lats, 
            cloudiness, 
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

#Incorporate the other graph properties
plt.title(f'City Latitude vs. CLoudiness (%) '+ time.strftime('%x'))
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid(True)

#Save the figure
plt.savefig('weather_data/Fig3.png')

#Show plot
plt.show()

# %%
#Build the scatter plot for latitude vs. wind speed
plt.scatter(lats, 
            wind_speed, 
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

#Incorporate the other graph properties
plt.title(f'City Latitude vs. Wind Speed '+ time.strftime('%x'))
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.grid(True)

#Save the figure
plt.savefig('weather_data/Fig4.png')

#Show plot
plt.show()

# %%
#Import linregress
from scipy.stats import linregress

#Create a function to perform linear regression on the weather data and plot a regression line with the equation
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    #Run regression on hemisphere weather data
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    #Calculate the regression line "y values" from the slope and intercept
    regress_values = x_values * slope + intercept
    #Get the equation of the line
    line_eq = "y = " + str(round(slope,2)) + "x + " +str(round(intercept,2))
    
    #Create a scatter plot and plot the regression line
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r")
    
    #Annotate the text for the line equation
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
#Create Northern and Southern Hemisphere data frames
northern_hemi_df = city_data_df.loc[(city_data_df['Lat'] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df['Lat'] < 0)]

northern_hemi_df.head()
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 1     Klaksvik      FO  2021-06-08 14:05:51  62.2266   -6.5890     50.92
# 4       Fallon      US  2021-06-08 14:05:52  39.4735 -118.7774     60.58
# 5        Togur      RU  2021-06-08 14:05:52  58.3631   82.8265     41.81
# 7    Maryville      US  2021-06-08 14:04:23  35.7565  -83.9705     79.16
# 8  Provideniya      RU  2021-06-08 14:05:52  64.3833 -173.3000     34.59
#
#    Humidity  Cloudiness  Wind Speed
# 1        97          49       15.59
# 4        25           1        3.44
# 5        72          98       17.09
# 7        89          98        1.01
# 8        87          12        3.02

# %%
#Linear regression on the Northern Hemisphere (Max Temp)
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']

#Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere \n for Maximum Temperature', 
                       'Max Temp', (10,40))

# %%
#Linear regression on the Southern Hemisphere (Max Temp)
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']

#Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the Southern Hemisphere \n for Maximum Temperature', 
                       'Max Temp', (-50,90))

# %%
#Linear regression on the Northern Hemisphere (Humidity)
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']

#Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere \n for % Humidity', 
                       '% Humidity', (40,20))

# %%
#Linear regression on the Southern Hemisphere (Humidity)
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']

#Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the Southern Hemisphere \n for % Humidity', 
                       '% Humidity', (-50,15))

# %%
#Linear regression on the Northern Hemisphere (Cloudiness)
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']

#Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere \n for % Cloudiness', 
                       '% Cloudiness', (10,60))

# %%
#Linear regression on the Southern Hemisphere (Cloudiness)
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']

#Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the Southern Hemisphere \n for % Cloudiness', 
                       '% Cloudiness', (-50,60))

# %%
#Linear regression on the Northern Hemisphere (Wind Speed)
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']

#Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere \n for Wind Speed', 
                       'Wind Speed', (40,35))

# %%
#Linear regression on the Southern Hemisphere (Wind Speed)
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']

#Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the Southern Hemisphere \n for Wind Speed', 
                       'Wind Speed', (-50,15))
