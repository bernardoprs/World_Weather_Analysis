# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

#This zip objects packs each pair of lats and lngs having the same index in their respective array into a tuple

# %%
#Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
#Use the citipy module to determine city based on latitude and longitude
from citipy import citipy

# %%
#Create a list for holding the cities
cities = []

#Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
#Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %%
#Import dependencies
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create an empty list to hold the weather data
city_data = []

#Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters
record_count = 1
set_count = 1

#Loop through all the cities in our list
for i, city in enumerate(cities):
    #Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    #Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    #Add 1 toS the record count
    record_count += 1
    ### Code Breakdown ###
    #Create a for loop with the enumerate() method and reference the index and the city in the list
    #Check if the remainder of the index divided by 50 is equal to zero, AND if the index is greater than or equal to 50,
    # using a conditional statement.
    #Create a URL endpoint in the conditional statement. However, we are removing blank spaces in the city name and 
    # concatenating the city name using city.replace(" ","+"). This will find the corresponding weather data for the city
    # instead of finding the weather data for the first part of the city name.
    #Add a print statement that tells the record count, set count, and the city that is being processed
    #Then add 1 to the record count before the next city is processed

#Run an API request for each of the cites 
    try:
        #Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        #Parse out the needed data
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        #Convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        #Append the city information into city_data list
        city_data.append({'City': city.title(),
                          'Lat': city_lat, 
                          'Lng': city_lng, 
                          'Max Temp': city_max_temp, 
                          'Humidity': city_humidity, 
                          'Cloudiness': city_clouds, 
                          'Wind Speed': city_wind, 
                          'Country': city_country, 
                          'Date': city_date})
#If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

#Indicate that the Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

    ### Code Breakdown ###
    #Parse the JSON file for the current city.
    #If there is weather data for the city, the metrics are retrieved.
    #The cities list is appended with a dictionary for that city, where the key value pairs 
    # are the values from the parameters.
    #Add the try and except block.
    #Add a pass statement to handle all errors encountered and to allow the program to continue.
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 1 | goderich
# Processing Record 4 of Set 1 | lompoc
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | merauke
# Processing Record 7 of Set 1 | guerrero negro
# Processing Record 8 of Set 1 | rio grande
# Processing Record 9 of Set 1 | naples
# Processing Record 10 of Set 1 | mehamn
# Processing Record 11 of Set 1 | fortuna
# Processing Record 12 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | qaanaaq
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | shakawe
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | bowen
# Processing Record 21 of Set 1 | xingyi
# Processing Record 22 of Set 1 | llanes
# Processing Record 23 of Set 1 | avarua
# Processing Record 24 of Set 1 | severo-kurilsk
# Processing Record 25 of Set 1 | clyde river
# Processing Record 26 of Set 1 | bredasdorp
# Processing Record 27 of Set 1 | tasiilaq
# Processing Record 28 of Set 1 | garowe
# Processing Record 29 of Set 1 | barrow
# Processing Record 30 of Set 1 | sile
# Processing Record 31 of Set 1 | bonthe
# Processing Record 32 of Set 1 | arukutti
# Processing Record 33 of Set 1 | portland
# Processing Record 34 of Set 1 | sawtell
# Processing Record 35 of Set 1 | karakendzha
# City not found. Skipping...
# Processing Record 36 of Set 1 | tuktoyaktuk
# Processing Record 37 of Set 1 | wahran
# City not found. Skipping...
# Processing Record 38 of Set 1 | hermanus
# Processing Record 39 of Set 1 | luanda
# Processing Record 40 of Set 1 | hanzhong
# Processing Record 41 of Set 1 | rikitea
# Processing Record 42 of Set 1 | albany
# Processing Record 43 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 44 of Set 1 | paracuru
# Processing Record 45 of Set 1 | upernavik
# Processing Record 46 of Set 1 | chokurdakh
# Processing Record 47 of Set 1 | thompson
# Processing Record 48 of Set 1 | lagoa
# Processing Record 49 of Set 1 | cape town
# Processing Record 50 of Set 1 | bethel
# Processing Record 1 of Set 2 | independence
# Processing Record 2 of Set 2 | lavras
# Processing Record 3 of Set 2 | canela
# Processing Record 4 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 2 | sao filipe
# Processing Record 6 of Set 2 | kpandae
# Processing Record 7 of Set 2 | klamath falls
# Processing Record 8 of Set 2 | arraial do cabo
# Processing Record 9 of Set 2 | isangel
# Processing Record 10 of Set 2 | tidore
# City not found. Skipping...
# Processing Record 11 of Set 2 | hilo
# Processing Record 12 of Set 2 | thinadhoo
# Processing Record 13 of Set 2 | atuona
# Processing Record 14 of Set 2 | saskylakh
# Processing Record 15 of Set 2 | morondava
# Processing Record 16 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 2 | ribeira grande
# Processing Record 18 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 19 of Set 2 | sitka
# Processing Record 20 of Set 2 | bambous virieux
# Processing Record 21 of Set 2 | east london
# Processing Record 22 of Set 2 | tongren
# Processing Record 23 of Set 2 | dunedin
# Processing Record 24 of Set 2 | inongo
# Processing Record 25 of Set 2 | bengkulu
# Processing Record 26 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 2 | mahibadhoo
# Processing Record 28 of Set 2 | susanville
# Processing Record 29 of Set 2 | airai
# Processing Record 30 of Set 2 | pecos
# Processing Record 31 of Set 2 | sao jose da coroa grande
# Processing Record 32 of Set 2 | bol
# Processing Record 33 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 2 | egvekinot
# Processing Record 35 of Set 2 | huilong
# Processing Record 36 of Set 2 | hervey bay
# Processing Record 37 of Set 2 | marsh harbour
# Processing Record 38 of Set 2 | tiksi
# Processing Record 39 of Set 2 | kapaa
# Processing Record 40 of Set 2 | mantua
# Processing Record 41 of Set 2 | yumen
# Processing Record 42 of Set 2 | undory
# Processing Record 43 of Set 2 | waddan
# Processing Record 44 of Set 2 | jamestown
# Processing Record 45 of Set 2 | pinheiral
# Processing Record 46 of Set 2 | lebu
# Processing Record 47 of Set 2 | zapolyarnyy
# Processing Record 48 of Set 2 | hithadhoo
# Processing Record 49 of Set 2 | hofn
# Processing Record 50 of Set 2 | yabelo
# Processing Record 1 of Set 3 | longyearbyen
# Processing Record 2 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 3 | rio gallegos
# Processing Record 4 of Set 3 | pacific grove
# Processing Record 5 of Set 3 | khatanga
# Processing Record 6 of Set 3 | kerki
# City not found. Skipping...
# Processing Record 7 of Set 3 | buraydah
# Processing Record 8 of Set 3 | westpunt
# City not found. Skipping...
# Processing Record 9 of Set 3 | sijunjung
# Processing Record 10 of Set 3 | tabory
# Processing Record 11 of Set 3 | nanortalik
# Processing Record 12 of Set 3 | new norfolk
# Processing Record 13 of Set 3 | sobolevo
# Processing Record 14 of Set 3 | saint-philippe
# Processing Record 15 of Set 3 | anadyr
# Processing Record 16 of Set 3 | port lincoln
# Processing Record 17 of Set 3 | cap malheureux
# Processing Record 18 of Set 3 | yorosso
# Processing Record 19 of Set 3 | veinticinco de mayo
# Processing Record 20 of Set 3 | drayton valley
# Processing Record 21 of Set 3 | chuy
# Processing Record 22 of Set 3 | kolondieba
# Processing Record 23 of Set 3 | broken hill
# Processing Record 24 of Set 3 | santa vitoria do palmar
# Processing Record 25 of Set 3 | saint george
# Processing Record 26 of Set 3 | malinovoye ozero
# Processing Record 27 of Set 3 | richards bay
# Processing Record 28 of Set 3 | bambanglipuro
# Processing Record 29 of Set 3 | aklavik
# Processing Record 30 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 3 | port-gentil
# Processing Record 32 of Set 3 | butaritari
# Processing Record 33 of Set 3 | carmelo
# Processing Record 34 of Set 3 | maloy
# Processing Record 35 of Set 3 | iskateley
# Processing Record 36 of Set 3 | port macquarie
# Processing Record 37 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 3 | sao paulo de olivenca
# Processing Record 39 of Set 3 | san pedro
# Processing Record 40 of Set 3 | bathsheba
# Processing Record 41 of Set 3 | leshukonskoye
# Processing Record 42 of Set 3 | havre-saint-pierre
# Processing Record 43 of Set 3 | gympie
# Processing Record 44 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 45 of Set 3 | kodiak
# Processing Record 46 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 47 of Set 3 | bluff
# Processing Record 48 of Set 3 | namibe
# Processing Record 49 of Set 3 | mahebourg
# Processing Record 50 of Set 3 | tessalit
# Processing Record 1 of Set 4 | dingle
# Processing Record 2 of Set 4 | shushtar
# Processing Record 3 of Set 4 | bairnsdale
# Processing Record 4 of Set 4 | mandera
# Processing Record 5 of Set 4 | port elizabeth
# Processing Record 6 of Set 4 | port alfred
# Processing Record 7 of Set 4 | ponta do sol
# Processing Record 8 of Set 4 | shingu
# Processing Record 9 of Set 4 | carnarvon
# Processing Record 10 of Set 4 | mar del plata
# Processing Record 11 of Set 4 | vestmannaeyjar
# Processing Record 12 of Set 4 | balkanabat
# Processing Record 13 of Set 4 | puri
# Processing Record 14 of Set 4 | hasaki
# Processing Record 15 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 4 | beringovskiy
# Processing Record 17 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 4 | kaitangata
# Processing Record 19 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 4 | caborca
# Processing Record 21 of Set 4 | sapai
# City not found. Skipping...
# Processing Record 22 of Set 4 | giresun
# Processing Record 23 of Set 4 | puerto ayora
# Processing Record 24 of Set 4 | sao joao da barra
# Processing Record 25 of Set 4 | sakaiminato
# Processing Record 26 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 27 of Set 4 | bagotville
# Processing Record 28 of Set 4 | sinalunga
# Processing Record 29 of Set 4 | qasigiannguit
# Processing Record 30 of Set 4 | bardiyah
# Processing Record 31 of Set 4 | kjopsvik
# Processing Record 32 of Set 4 | half moon bay
# Processing Record 33 of Set 4 | sept-iles
# Processing Record 34 of Set 4 | bar harbor
# Processing Record 35 of Set 4 | tura
# Processing Record 36 of Set 4 | aykhal
# Processing Record 37 of Set 4 | narsaq
# Processing Record 38 of Set 4 | torbay
# Processing Record 39 of Set 4 | westport
# Processing Record 40 of Set 4 | villa del rosario
# Processing Record 41 of Set 4 | port moresby
# Processing Record 42 of Set 4 | cabo san lucas
# Processing Record 43 of Set 4 | berlevag
# Processing Record 44 of Set 4 | koforidua
# Processing Record 45 of Set 4 | imbituba
# Processing Record 46 of Set 4 | belawan
# Processing Record 47 of Set 4 | lorengau
# Processing Record 48 of Set 4 | terrace bay
# Processing Record 49 of Set 4 | kiruna
# Processing Record 50 of Set 4 | matagami
# Processing Record 1 of Set 5 | sur
# Processing Record 2 of Set 5 | pingzhuang
# Processing Record 3 of Set 5 | gangotri
# City not found. Skipping...
# Processing Record 4 of Set 5 | dikson
# Processing Record 5 of Set 5 | puqi
# Processing Record 6 of Set 5 | coquimbo
# Processing Record 7 of Set 5 | urozhaynoye
# Processing Record 8 of Set 5 | araouane
# Processing Record 9 of Set 5 | saldanha
# Processing Record 10 of Set 5 | kilindoni
# Processing Record 11 of Set 5 | amahai
# Processing Record 12 of Set 5 | krasnaya gora
# Processing Record 13 of Set 5 | ola
# Processing Record 14 of Set 5 | norman wells
# Processing Record 15 of Set 5 | maiduguri
# Processing Record 16 of Set 5 | college
# Processing Record 17 of Set 5 | atikokan
# Processing Record 18 of Set 5 | altay
# Processing Record 19 of Set 5 | kununurra
# Processing Record 20 of Set 5 | alofi
# Processing Record 21 of Set 5 | ancud
# Processing Record 22 of Set 5 | walvis bay
# Processing Record 23 of Set 5 | kholodnyy
# Processing Record 24 of Set 5 | vardo
# Processing Record 25 of Set 5 | castro
# Processing Record 26 of Set 5 | kasongo-lunda
# Processing Record 27 of Set 5 | sabya
# Processing Record 28 of Set 5 | dong hoi
# Processing Record 29 of Set 5 | krasnoselkup
# Processing Record 30 of Set 5 | toftir
# City not found. Skipping...
# Processing Record 31 of Set 5 | hambantota
# Processing Record 32 of Set 5 | geraldton
# Processing Record 33 of Set 5 | maseru
# Processing Record 34 of Set 5 | galesong
# Processing Record 35 of Set 5 | high prairie
# Processing Record 36 of Set 5 | abu dhabi
# Processing Record 37 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 5 | polson
# Processing Record 39 of Set 5 | la grande
# Processing Record 40 of Set 5 | fairbanks
# Processing Record 41 of Set 5 | luba
# Processing Record 42 of Set 5 | provideniya
# Processing Record 43 of Set 5 | xining
# Processing Record 44 of Set 5 | great yarmouth
# Processing Record 45 of Set 5 | nikolskoye
# Processing Record 46 of Set 5 | arona
# Processing Record 47 of Set 5 | hovd
# Processing Record 48 of Set 5 | riohacha
# Processing Record 49 of Set 5 | ostrovnoy
# Processing Record 50 of Set 5 | akyab
# Processing Record 1 of Set 6 | oksfjord
# Processing Record 2 of Set 6 | bitung
# Processing Record 3 of Set 6 | riwaka
# Processing Record 4 of Set 6 | kuching
# Processing Record 5 of Set 6 | brokopondo
# Processing Record 6 of Set 6 | sabha
# Processing Record 7 of Set 6 | esperance
# Processing Record 8 of Set 6 | cotonou
# Processing Record 9 of Set 6 | pleasanton
# Processing Record 10 of Set 6 | piacabucu
# Processing Record 11 of Set 6 | san quintin
# Processing Record 12 of Set 6 | jumla
# Processing Record 13 of Set 6 | ust-tsilma
# Processing Record 14 of Set 6 | ozinki
# Processing Record 15 of Set 6 | talnakh
# Processing Record 16 of Set 6 | petatlan
# Processing Record 17 of Set 6 | bubaque
# Processing Record 18 of Set 6 | nome
# Processing Record 19 of Set 6 | solton
# Processing Record 20 of Set 6 | acapulco
# Processing Record 21 of Set 6 | alice springs
# Processing Record 22 of Set 6 | sittingbourne
# Processing Record 23 of Set 6 | necochea
# Processing Record 24 of Set 6 | honningsvag
# Processing Record 25 of Set 6 | adelaide
# Processing Record 26 of Set 6 | nelson bay
# Processing Record 27 of Set 6 | waingapu
# Processing Record 28 of Set 6 | vittorio veneto
# Processing Record 29 of Set 6 | devrek
# Processing Record 30 of Set 6 | honiara
# Processing Record 31 of Set 6 | ibarra
# Processing Record 32 of Set 6 | nouadhibou
# Processing Record 33 of Set 6 | caravelas
# Processing Record 34 of Set 6 | sakakah
# Processing Record 35 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 6 | gualaquiza
# Processing Record 37 of Set 6 | mwense
# Processing Record 38 of Set 6 | waw
# Processing Record 39 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 6 | yulara
# Processing Record 41 of Set 6 | kaabong
# Processing Record 42 of Set 6 | santa lucia
# Processing Record 43 of Set 6 | fort nelson
# Processing Record 44 of Set 6 | tahta
# Processing Record 45 of Set 6 | oranjemund
# Processing Record 46 of Set 6 | talavera de la reina
# Processing Record 47 of Set 6 | kang
# Processing Record 48 of Set 6 | nuuk
# Processing Record 49 of Set 6 | faanui
# Processing Record 50 of Set 6 | khandbari
# Processing Record 1 of Set 7 | baculin
# Processing Record 2 of Set 7 | borujan
# City not found. Skipping...
# Processing Record 3 of Set 7 | atar
# Processing Record 4 of Set 7 | shuyskoye
# Processing Record 5 of Set 7 | udachnyy
# Processing Record 6 of Set 7 | shimanovsk
# Processing Record 7 of Set 7 | ugoofaaru
# Processing Record 8 of Set 7 | indianola
# Processing Record 9 of Set 7 | chara
# Processing Record 10 of Set 7 | vila franca do campo
# Processing Record 11 of Set 7 | novozavidovskiy
# Processing Record 12 of Set 7 | antofagasta
# Processing Record 13 of Set 7 | bababe
# City not found. Skipping...
# Processing Record 14 of Set 7 | kedrovyy
# Processing Record 15 of Set 7 | carolina
# Processing Record 16 of Set 7 | takoradi
# Processing Record 17 of Set 7 | tiznit
# Processing Record 18 of Set 7 | sosnovo-ozerskoye
# Processing Record 19 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 20 of Set 7 | hit
# Processing Record 21 of Set 7 | wanning
# Processing Record 22 of Set 7 | birjand
# Processing Record 23 of Set 7 | srednekolymsk
# Processing Record 24 of Set 7 | praya
# Processing Record 25 of Set 7 | bindura
# Processing Record 26 of Set 7 | callaguip
# Processing Record 27 of Set 7 | cayenne
# Processing Record 28 of Set 7 | tuatapere
# Processing Record 29 of Set 7 | port hedland
# Processing Record 30 of Set 7 | inuvik
# Processing Record 31 of Set 7 | anito
# Processing Record 32 of Set 7 | manvi
# Processing Record 33 of Set 7 | oildale
# Processing Record 34 of Set 7 | sabang
# Processing Record 35 of Set 7 | launceston
# Processing Record 36 of Set 7 | umm durman
# City not found. Skipping...
# Processing Record 37 of Set 7 | iqaluit
# Processing Record 38 of Set 7 | georgetown
# Processing Record 39 of Set 7 | cidreira
# Processing Record 40 of Set 7 | comodoro rivadavia
# Processing Record 41 of Set 7 | taoudenni
# Processing Record 42 of Set 7 | miandrivazo
# Processing Record 43 of Set 7 | disa
# Processing Record 44 of Set 7 | zhoucheng
# Processing Record 45 of Set 7 | lakatoro
# Processing Record 46 of Set 7 | kruisfontein
# Processing Record 47 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 7 | manakara
# Processing Record 49 of Set 7 | viransehir
# Processing Record 50 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 1 of Set 8 | vyazemskiy
# Processing Record 2 of Set 8 | madang
# Processing Record 3 of Set 8 | balikpapan
# Processing Record 4 of Set 8 | sauce
# Processing Record 5 of Set 8 | pisco
# Processing Record 6 of Set 8 | zaysan
# Processing Record 7 of Set 8 | sexsmith
# Processing Record 8 of Set 8 | ipixuna
# Processing Record 9 of Set 8 | batagay-alyta
# Processing Record 10 of Set 8 | hulan ergi
# Processing Record 11 of Set 8 | kahului
# Processing Record 12 of Set 8 | nemuro
# Processing Record 13 of Set 8 | touros
# Processing Record 14 of Set 8 | luderitz
# Processing Record 15 of Set 8 | hargeysa
# Processing Record 16 of Set 8 | hamilton
# Processing Record 17 of Set 8 | eghezee
# Processing Record 18 of Set 8 | chimbote
# Processing Record 19 of Set 8 | napanee
# Processing Record 20 of Set 8 | awjilah
# Processing Record 21 of Set 8 | paisley
# Processing Record 22 of Set 8 | adrar
# Processing Record 23 of Set 8 | siocon
# Processing Record 24 of Set 8 | nouakchott
# Processing Record 25 of Set 8 | grand gaube
# Processing Record 26 of Set 8 | azimur
# City not found. Skipping...
# Processing Record 27 of Set 8 | maniitsoq
# Processing Record 28 of Set 8 | broome
# Processing Record 29 of Set 8 | el paso
# Processing Record 30 of Set 8 | inhambane
# Processing Record 31 of Set 8 | salta
# Processing Record 32 of Set 8 | vila velha
# Processing Record 33 of Set 8 | port keats
# Processing Record 34 of Set 8 | mbaiki
# Processing Record 35 of Set 8 | kamaishi
# Processing Record 36 of Set 8 | salalah
# Processing Record 37 of Set 8 | chone
# Processing Record 38 of Set 8 | maumere
# Processing Record 39 of Set 8 | minna
# Processing Record 40 of Set 8 | pevek
# Processing Record 41 of Set 8 | datong
# Processing Record 42 of Set 8 | klaksvik
# Processing Record 43 of Set 8 | shanghai
# Processing Record 44 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 45 of Set 8 | sembakung
# Processing Record 46 of Set 8 | soe
# Processing Record 47 of Set 8 | colonia
# Processing Record 48 of Set 8 | helsingborg
# Processing Record 49 of Set 8 | manaure
# Processing Record 50 of Set 8 | misratah
# Processing Record 1 of Set 9 | avera
# Processing Record 2 of Set 9 | naze
# Processing Record 3 of Set 9 | la ronge
# Processing Record 4 of Set 9 | pasni
# Processing Record 5 of Set 9 | te anau
# Processing Record 6 of Set 9 | lavrentiya
# Processing Record 7 of Set 9 | aroysund
# Processing Record 8 of Set 9 | trairi
# Processing Record 9 of Set 9 | mahadday weyne
# City not found. Skipping...
# Processing Record 10 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 11 of Set 9 | bandarbeyla
# Processing Record 12 of Set 9 | alihe
# Processing Record 13 of Set 9 | codrington
# Processing Record 14 of Set 9 | bahia de caraquez
# Processing Record 15 of Set 9 | poum
# Processing Record 16 of Set 9 | kavaratti
# Processing Record 17 of Set 9 | villa carlos paz
# Processing Record 18 of Set 9 | oktyabrskoye
# Processing Record 19 of Set 9 | korla
# Processing Record 20 of Set 9 | yar-sale
# Processing Record 21 of Set 9 | ilulissat
# Processing Record 22 of Set 9 | souillac
# Processing Record 23 of Set 9 | ottumwa
# Processing Record 24 of Set 9 | ramshir
# Processing Record 25 of Set 9 | griffith
# Processing Record 26 of Set 9 | san miguel
# Processing Record 27 of Set 9 | klyuchi
# Processing Record 28 of Set 9 | palaikastron
# Processing Record 29 of Set 9 | rocha
# Processing Record 30 of Set 9 | awbari
# Processing Record 31 of Set 9 | kirakira
# Processing Record 32 of Set 9 | porto novo
# Processing Record 33 of Set 9 | vryburg
# Processing Record 34 of Set 9 | yinchuan
# Processing Record 35 of Set 9 | blonduos
# City not found. Skipping...
# Processing Record 36 of Set 9 | benghazi
# Processing Record 37 of Set 9 | mandalgovi
# Processing Record 38 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 39 of Set 9 | baykit
# Processing Record 40 of Set 9 | karasjok
# Processing Record 41 of Set 9 | ikalamavony
# Processing Record 42 of Set 9 | xiaoshi
# Processing Record 43 of Set 9 | namangan
# Processing Record 44 of Set 9 | stanita
# Processing Record 45 of Set 9 | shirgaon
# Processing Record 46 of Set 9 | general cepeda
# Processing Record 47 of Set 9 | charcas
# Processing Record 48 of Set 9 | filadelfia
# Processing Record 49 of Set 9 | dujuma
# City not found. Skipping...
# Processing Record 50 of Set 9 | vangaindrano
# Processing Record 1 of Set 10 | khorramabad
# Processing Record 2 of Set 10 | umm lajj
# Processing Record 3 of Set 10 | bahar
# Processing Record 4 of Set 10 | san luis
# Processing Record 5 of Set 10 | lewisporte
# Processing Record 6 of Set 10 | ixtapa
# Processing Record 7 of Set 10 | townsville
# Processing Record 8 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 9 of Set 10 | umm kaddadah
# Processing Record 10 of Set 10 | puerto varas
# Processing Record 11 of Set 10 | sibolga
# Processing Record 12 of Set 10 | gamba
# Processing Record 13 of Set 10 | laguna
# Processing Record 14 of Set 10 | pimentel
# Processing Record 15 of Set 10 | saint-georges
# Processing Record 16 of Set 10 | greifswald
# Processing Record 17 of Set 10 | quito
# Processing Record 18 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 19 of Set 10 | saint-joseph
# Processing Record 20 of Set 10 | camacha
# Processing Record 21 of Set 10 | pitimbu
# Processing Record 22 of Set 10 | vagur
# Processing Record 23 of Set 10 | saint anthony
# Processing Record 24 of Set 10 | moroni
# Processing Record 25 of Set 10 | emmett
# Processing Record 26 of Set 10 | faya
# Processing Record 27 of Set 10 | coihaique
# Processing Record 28 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 29 of Set 10 | la paz
# Processing Record 30 of Set 10 | cumberland
# Processing Record 31 of Set 10 | turukhansk
# Processing Record 32 of Set 10 | felipe carrillo puerto
# Processing Record 33 of Set 10 | ossora
# Processing Record 34 of Set 10 | mount gambier
# Processing Record 35 of Set 10 | birao
# Processing Record 36 of Set 10 | birzai
# Processing Record 37 of Set 10 | ewo
# Processing Record 38 of Set 10 | shatalovo
# Processing Record 39 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 40 of Set 10 | muros
# Processing Record 41 of Set 10 | saint-michel-des-saints
# Processing Record 42 of Set 10 | mocuba
# Processing Record 43 of Set 10 | sanguem
# Processing Record 44 of Set 10 | tamale
# Processing Record 45 of Set 10 | pochutla
# Processing Record 46 of Set 10 | conceicao da barra
# Processing Record 47 of Set 10 | xalpatlahuac
# Processing Record 48 of Set 10 | leningradskiy
# Processing Record 49 of Set 10 | donskoye
# Processing Record 50 of Set 10 | pekan
# Processing Record 1 of Set 11 | cherskiy
# Processing Record 2 of Set 11 | abu jubayhah
# City not found. Skipping...
# Processing Record 3 of Set 11 | pout
# Processing Record 4 of Set 11 | belmonte
# Processing Record 5 of Set 11 | tarakan
# Processing Record 6 of Set 11 | tala
# Processing Record 7 of Set 11 | yerbogachen
# Processing Record 8 of Set 11 | roberval
# Processing Record 9 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 10 of Set 11 | taltal
# Processing Record 11 of Set 11 | dubasari
# Processing Record 12 of Set 11 | faridan
# City not found. Skipping...
# Processing Record 13 of Set 11 | strelka
# Processing Record 14 of Set 11 | kupang
# Processing Record 15 of Set 11 | haines junction
# Processing Record 16 of Set 11 | belyy yar
# Processing Record 17 of Set 11 | deputatskiy
# Processing Record 18 of Set 11 | sechura
# Processing Record 19 of Set 11 | bryan
# Processing Record 20 of Set 11 | dibulla
# Processing Record 21 of Set 11 | kavieng
# Processing Record 22 of Set 11 | coulihaut
# City not found. Skipping...
# Processing Record 23 of Set 11 | aksu
# Processing Record 24 of Set 11 | yazman
# Processing Record 25 of Set 11 | maldonado
# Processing Record 26 of Set 11 | andenes
# Processing Record 27 of Set 11 | sinnamary
# Processing Record 28 of Set 11 | bedele
# Processing Record 29 of Set 11 | eskilstuna
# Processing Record 30 of Set 11 | silifke
# Processing Record 31 of Set 11 | planaltina
# Processing Record 32 of Set 11 | velikiy ustyug
# Processing Record 33 of Set 11 | constitucion
# Processing Record 34 of Set 11 | celestun
# Processing Record 35 of Set 11 | kanniyakumari
# Processing Record 36 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 11 | vao
# Processing Record 38 of Set 11 | gurupi
# Processing Record 39 of Set 11 | togur
# Processing Record 40 of Set 11 | husavik
# Processing Record 41 of Set 11 | teseney
# Processing Record 42 of Set 11 | abu samrah
# Processing Record 43 of Set 11 | ahipara
# Processing Record 44 of Set 11 | olavarria
# Processing Record 45 of Set 11 | taburi
# City not found. Skipping...
# Processing Record 46 of Set 11 | brenham
# Processing Record 47 of Set 11 | dunda
# Processing Record 48 of Set 11 | boende
# Processing Record 49 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 50 of Set 11 | jackson
# Processing Record 1 of Set 12 | albion
# Processing Record 2 of Set 12 | alberdi
# Processing Record 3 of Set 12 | yichang
# Processing Record 4 of Set 12 | camocim
# Processing Record 5 of Set 12 | oskarshamn
# Processing Record 6 of Set 12 | komsomolskiy
# Processing Record 7 of Set 12 | tyrma
# Processing Record 8 of Set 12 | hilton head island
# Processing Record 9 of Set 12 | victoria
# Processing Record 10 of Set 12 | skelleftea
# Processing Record 11 of Set 12 | emba
# Processing Record 12 of Set 12 | gloversville
# Processing Record 13 of Set 12 | harper
# Processing Record 14 of Set 12 | fukue
# Processing Record 15 of Set 12 | dalhousie
# Processing Record 16 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 17 of Set 12 | kamenka
# Processing Record 18 of Set 12 | florianopolis
# Processing Record 19 of Set 12 | churapcha
# Processing Record 20 of Set 12 | jomalig
# City not found. Skipping...
# Processing Record 21 of Set 12 | along
# Processing Record 22 of Set 12 | annbank
# Processing Record 23 of Set 12 | valparaiso
# Processing Record 24 of Set 12 | meulaboh
# Processing Record 25 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 26 of Set 12 | arlit
# Processing Record 27 of Set 12 | san policarpo
# Processing Record 28 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 29 of Set 12 | ghanzi
# Processing Record 30 of Set 12 | gasa
# Processing Record 31 of Set 12 | likasi
# Processing Record 32 of Set 12 | sibut
# Processing Record 33 of Set 12 | maceio
# Processing Record 34 of Set 12 | tongzi
# Processing Record 35 of Set 12 | katy
# Processing Record 36 of Set 12 | bom jardim
# Processing Record 37 of Set 12 | monterey
# Processing Record 38 of Set 12 | olinda
# Processing Record 39 of Set 12 | pocone
# Processing Record 40 of Set 12 | verkhoyansk
# Processing Record 41 of Set 12 | erenhot
# Processing Record 42 of Set 12 | palaiokhora
# City not found. Skipping...
# Processing Record 43 of Set 12 | surt
# Processing Record 44 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 45 of Set 12 | san jose
# Processing Record 46 of Set 12 | makakilo city
# Processing Record 47 of Set 12 | ikom
# Processing Record 48 of Set 12 | halifax
# Processing Record 49 of Set 12 | sladkovo
# Processing Record 50 of Set 12 | yueyang
# Processing Record 1 of Set 13 | asau
# Processing Record 2 of Set 13 | rumoi
# Processing Record 3 of Set 13 | iquique
# Processing Record 4 of Set 13 | weihe
# Processing Record 5 of Set 13 | itarema
# Processing Record 6 of Set 13 | qaqortoq
# Processing Record 7 of Set 13 | tumannyy
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 549

# %%
#Convert the array of dictionaries into a Pandas data frame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Mataura -46.1927  168.8643     49.48        82          17
# 1        Goderich  43.7501  -81.7165     75.20        84          28
# 2          Lompoc  34.6391 -120.4579     60.78        81          90
# 3         Ushuaia -54.8000  -68.3000     29.86       100           0
# 4         Merauke  -8.4667  140.3333     80.35        82          92
# 5  Guerrero Negro  27.9769 -114.0611     63.21        84          99
# 6      Rio Grande -32.0350  -52.0986     58.95        94         100
# 7          Naples  40.8333   14.2500     68.14        77          75
# 8          Mehamn  71.0357   27.8492     41.81        76          11
# 9         Fortuna  40.5982 -124.1573     54.09        72           1
#
#    Wind Speed Country                 Date
# 0        0.25      NZ  2021-06-06 04:11:12
# 1       14.00      CA  2021-06-06 04:11:12
# 2        6.91      US  2021-06-06 04:11:12
# 3        9.22      AR  2021-06-06 04:11:13
# 4       15.14      ID  2021-06-06 04:11:13
# 5       13.73      MX  2021-06-06 04:11:13
# 6       11.81      BR  2021-06-06 04:10:12
# 7        1.14      IT  2021-06-06 04:07:11
# 8       20.47      NO  2021-06-06 04:11:14
# 9        4.00      US  2021-06-06 04:10:00

# %%
#Reorder the columns
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0         Mataura      NZ  2021-06-06 04:11:12 -46.1927  168.8643     49.48
# 1        Goderich      CA  2021-06-06 04:11:12  43.7501  -81.7165     75.20
# 2          Lompoc      US  2021-06-06 04:11:12  34.6391 -120.4579     60.78
# 3         Ushuaia      AR  2021-06-06 04:11:13 -54.8000  -68.3000     29.86
# 4         Merauke      ID  2021-06-06 04:11:13  -8.4667  140.3333     80.35
# 5  Guerrero Negro      MX  2021-06-06 04:11:13  27.9769 -114.0611     63.21
# 6      Rio Grande      BR  2021-06-06 04:10:12 -32.0350  -52.0986     58.95
# 7          Naples      IT  2021-06-06 04:07:11  40.8333   14.2500     68.14
# 8          Mehamn      NO  2021-06-06 04:11:14  71.0357   27.8492     41.81
# 9         Fortuna      US  2021-06-06 04:10:00  40.5982 -124.1573     54.09
#
#    Humidity  Cloudiness  Wind Speed
# 0        82          17        0.25
# 1        84          28       14.00
# 2        81          90        6.91
# 3       100           0        9.22
# 4        82          92       15.14
# 5        84          99       13.73
# 6        94         100       11.81
# 7        77          75        1.14
# 8        76          11       20.47
# 9        72           1        4.00

# %%
#Create the output file (CSV)
output_data_file = "weather_data/cities.csv"

#Export the city_data into a CSV
city_data_df.to_csv(output_data_file, index_label='City_ID')

# %%
#Extract relevant fields from the data frame for plotting
lats = city_data_df['Lat']
max_temps = city_data_df['Max Temp']
humidity = city_data_df['Humidity']
cloudiness = city_data_df['Cloudiness']
wind_speed = city_data_df['Wind Speed']

# %%
#Import time module
import time

#Build the scatter plot for latitude vs. max temperature
plt.scatter(lats, 
            max_temps, 
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

#Incorporate the other graph properties
plt.title(f'City Latitude vs. Max Temperature '+ time.strftime('%x'))
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.grid(True)

#Save the figure
plt.savefig('weather_data/Fig1.png')

#Show plot
plt.show()

# %%
#Build the scatter plots for latitude vs. humidity
plt.scatter(lats, 
            humidity, 
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

#Incorporate the other graph properties
plt.title(f'City Latitude vs. Humidity '+ time.strftime('%x'))
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.grid(True)

#Save the figure
plt.savefig('weather_data/Fig2.png')

#Show plot
plt.show()

# %%
#Build the scatter plot for latitude vs. cloudiness
plt.scatter(lats, 
            cloudiness, 
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

#Incorporate the other graph properties
plt.title(f'City Latitude vs. CLoudiness (%) '+ time.strftime('%x'))
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid(True)

#Save the figure
plt.savefig('weather_data/Fig3.png')

#Show plot
plt.show()

# %%
#Build the scatter plot for latitude vs. wind speed
plt.scatter(lats, 
            wind_speed, 
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

#Incorporate the other graph properties
plt.title(f'City Latitude vs. Wind Speed '+ time.strftime('%x'))
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.grid(True)

#Save the figure
plt.savefig('weather_data/Fig4.png')

#Show plot
plt.show()

# %%
#Import linregress
from scipy.stats import linregress

#Create a function to perform linear regression on the weather data and plot a regression line with the equation
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    #Run regression on hemisphere weather data
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    #Calculate the regression line "y values" from the slope and intercept
    regress_values = x_values * slope + intercept
    #Get the equation of the line
    line_eq = "y = " + str(round(slope,2)) + "x + " +str(round(intercept,2))
    
    #Create a scatter plot and plot the regression line
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r")
    
    #Annotate the text for the line equation
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
#Create Northern and Southern Hemisphere data frames
northern_hemi_df = city_data_df.loc[(city_data_df['Lat'] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df['Lat'] < 0)]

northern_hemi_df.head()
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 1        Goderich      CA  2021-06-06 04:11:12  43.7501  -81.7165     75.20
# 2          Lompoc      US  2021-06-06 04:11:12  34.6391 -120.4579     60.78
# 5  Guerrero Negro      MX  2021-06-06 04:11:13  27.9769 -114.0611     63.21
# 7          Naples      IT  2021-06-06 04:07:11  40.8333   14.2500     68.14
# 8          Mehamn      NO  2021-06-06 04:11:14  71.0357   27.8492     41.81
#
#    Humidity  Cloudiness  Wind Speed
# 1        84          28       14.00
# 2        81          90        6.91
# 5        84          99       13.73
# 7        77          75        1.14
# 8        76          11       20.47

# %%
#Linear regression on the Northern Hemisphere (Max Temp)
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']

#Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere \n for Maximum Temperature', 
                       'Max Temp', (10,40))

# %%
#Linear regression on the Southern Hemisphere (Max Temp)
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']

#Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the Southern Hemisphere \n for Maximum Temperature', 
                       'Max Temp', (-50,90))

# %%
#Linear regression on the Northern Hemisphere (Humidity)
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']

#Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere \n for % Humidity', 
                       '% Humidity', (40,20))

# %%
#Linear regression on the Southern Hemisphere (Humidity)
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']

#Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the Southern Hemisphere \n for % Humidity', 
                       '% Humidity', (-50,15))

# %%
#Linear regression on the Northern Hemisphere (Cloudiness)
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']

#Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere \n for % Cloudiness', 
                       '% Cloudiness', (10,60))

# %%
#Linear regression on the Southern Hemisphere (Cloudiness)
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']

#Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the Southern Hemisphere \n for % Cloudiness', 
                       '% Cloudiness', (-50,60))

# %%
#Linear regression on the Northern Hemisphere (Wind Speed)
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']

#Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere \n for Wind Speed', 
                       'Wind Speed', (40,35))

# %%
#Linear regression on the Southern Hemisphere (Wind Speed)
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']

#Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the Southern Hemisphere \n for Wind Speed', 
                       'Wind Speed', (-50,15))
